# %%
# Function for integreating ODE and displaying results
import scipy.integrate
from scipy.integrate import odeint
import numpy as np
import matplotlib.pylab as plt
import math
from math import exp
from scipy.interpolate import spline
# %matplotlib inline

import numpy.random as npr
# normal random distribution
from numpy.random import normal as nprn
# uniform random distribution
from numpy.random import uniform as npru

# %%
plt.figure(figsize=(12,18))

# Khadra P2X7 HEK BzATP st 40s 320 uM
t1 = np.array([0,0.2380952381,0.9523809524,2.261904762,3.09523809,5.595238095,21.30952381,39.88095238,41.07142857,42.61904762,44.64285714,47.26190476,52.26190476])   
# Khadra P2X7 HEK BzATP st 693s 3.2 uM
t2 = np.array([0,17.01030928,44.84536082,81.95876289,119.0721649,262.8865979,429.8969072,618.556701,692.7835052,706.7010309,742.2680412,787.1134021])
# Khadra P2X7 HEK BzATP st 697s 320 uM
t3 = np.array([0,1.546391753,12.37113402,44.84536082,86.59793814,154.6391753,264.4329897,428.3505155,694.3298969,705.1546392,787.1134021])
# Khadra P2X7 HEK BzATP st 304s 100 uM
t4 = np.array([0,1.739130435,4.347826087,9.739130435,21.2173913,42.7826087,95.39130435,157.3913043,306.4347826,313.6521739,322.7826087,338.2608696,361.2173913,391.9130435,410.6086957])
# Yan P2X7 HEK BzATP st 120s 3.2 uM
t5 = np.array([0,9.034220532,25.00380228,56.94296578,116.2585551,151.391635,203.8631179,230.3269962])
# Yan P2X7 HEK BzATP st 120s 10 uM
t6 = np.array([0,13.28244275,38.47328244,80.15267176,122.2900763,142.9007634,173.5877863,223.5114504])
# Yan P2X7 HEK BzATP st 40s 32 uM
t7 = np.array([0,0.5369127517,6.174496644,12.34899329,20.93959732,39.73154362,42.95302013,48.32214765,54.22818792,69.79865772,136.1073826])
# Yan P2X7 HEK BzATP st 40s 320 uM
t8 = np.array([0,0.5555555556,1.666666667,2.777777778,4.166666667,9.722222222,16.94444444,38.61111111,48.05555556,55.83333333,64.16666667,70.55555556,98.88888889])
# Egan P2X7 HEK BzATP st 3s 100 uM
t9 = np.array([0,0.1126760563,0.2253521127,0.5633802817,1.098591549,1.605633803,2.366197183,2.873239437,3.154929577,3.436619718,3.774647887,4.422535211,5.436619718,6.704225352])
# Yan P2X7 HEK BzATP st 40s 100 uM
t22 = np.array([0,0.2777777778,1.111111111,1.944444444,3.055555556,6.666666667,12.5,17.5,23.05555556,25.55555556,39.16666667,46.94444444,52.22222222,62.22222222,93.61111111])

y1 = np.array([0,-0.2988326848,-0.5229571984,-0.4645914397,-0.46692607,-0.4949416342,-0.7680933852,-1.052918288,-0.5089494163,-0.2661478599,-0.08871595331,-0.02568093385,0])
y2 = np.array([0,-0.014875,-0.023625,-0.0245,-0.02296875,-0.01553125,-0.01203125,-0.011375,-0.0109375,-0.007875,-0.0056875,-0.00525])
y3 = np.array([0,-0.048375,-0.055125,-0.039375,-0.02925,-0.021,-0.01725,-0.0135,-0.01125,-0.003375,-0.002625])
y4 = np.array([0,-2.379457917,-2.339514979,-2.487874465,-3.007132668,-3.549215407,-3.994293866,-4.034236805,-3.994293866,-2.80171184,-1.940085592,-1.27532097,-0.6390870185,-0.3823109843,-0.3423680456])
y5 = np.array([0,-0.002661870504,-0.004820143885,-0.006582733813,-0.006582733813,-0.003669064748,-0.001366906475,-0.0007553956835])
y6 = np.array([0,-0.01758992806,-0.02482014388,-0.02611510791,-0.02449640288,-0.01521582734,-0.00928057554,-0.005611510791])
y7 = np.array([0,-0.1985611511,-0.2330935252,-0.3323741007,-0.5309352518,-1.122302158,-0.4230215827,-0.1726618705,-0.1035971223,-0.03021582734,-0.01294964029])
y8 = np.array([0,-3.008992806,-2.857913669,-2.807553957,-2.832733813,-3.147482014,-3.411870504,-3.348920863,-1.510791367,-0.8561151079,-0.5287769784,-0.4154676259,-0.3399280576])
y9 = np.array([0,-0.015,-0.06,-0.345,-0.585,-0.67125,-0.6975,-0.69,-0.42375,-0.2625,-0.1725,-0.105,-0.075,-0.04125])
y22 = np.array([0,-1.446043165,-1.251798561,-1.230215827,-1.284172662,-1.672661871,-2.363309353,-2.665467626,-2.838129496,-2.870503597,-2.870503597,-0.7661870504,-0.3669064748,-0.1618705036,-0.02158273381])

plt.subplot(3,2,1)
plt.tick_params(labelsize=12)
plt.plot(t1,y1,label="K-H-BzA-40s-320uM")
#plt.plot(t2,y2,label="K-H-BzA-693s-3.2uM")
#plt.plot(t3,y3,label="K-H-BzA-697s-320uM")
plt.plot(t4,y4,label="K-H-BzA-304s-100uM")
#plt.plot(t5,y5,label="Y-H-BzA-120s-3.2uM")
#plt.plot(t6,y6,label="Y-H-BzA-120s-10uM")
#plt.plot(t7,y7,label="Y-H-BzA-40s-32uM")
#plt.plot(t8,y8,label="Y-H-BzA-40s-320uM")
plt.plot(t9,y9,label="E-H-BzA-3s-100uM")
#plt.plot(t22,y22,label="Y-H-BzA-40s-100uM")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("current (nA)",fontsize=12)
plt.legend(loc=0,fontsize=12)

plt.subplot(3,2,2)
plt.tick_params(labelsize=12)
#plt.plot(t1,y1,label="K-H-BzA-40s-320uM")
#plt.plot(t2,y2,label="K-H-BzA-693s-3.2uM")
#plt.plot(t3,y3,label="K-H-BzA-697s-320uM")
#plt.plot(t4,y4,label="K-H-BzA-304s-100uM")
plt.plot(t5,y5,label="Y-H-BzA-120s-3.2uM")
plt.plot(t6,y6,label="Y-H-BzA-120s-10uM")
plt.plot(t7,y7,label="Y-H-BzA-40s-32uM")
plt.plot(t8,y8,label="Y-H-BzA-40s-320uM")
plt.plot(t9,y9,label="E-H-BzA-3s-100uM")
plt.plot(t22,y22,label="Y-H-BzA-40s-100uM")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("current (nA)",fontsize=12)
plt.legend(loc=0,fontsize=12)

# Khadra P2X7 HEK ATP st 15s 1000 uM
t10 = np.array([0,0.05952380952,0.2976190476,1.071428571,7.023809524,15.5952381,16.13095238,16.9047619,18.21428571])
# Yan P2X7 HEK ATP st 120s 320 uM
t11 = np.array([0,1.832061069,11.45038168,16.48854962,67.78625954,119.0839695,122.7480916,127.7862595])
# Yan P2X7 HEK ATP st 120s 100 uM
t12 = np.array([0,6.41221374,30.6870229,53.12977099,95.26717557,119.5419847,123.6641221,127.7862595])
# Yan P2X7 HEK ATP st 40s 10000 uM
t13 = np.array([0,0.2777777778,3.611111111,17.77777778,40,40.83333333,42.22222222,43.33333333])
# Yan P2X7 HEK ATP st 120s 3200 uM
t14 = np.array([0,0.9160305344,2.290076336,14.65648855,20.61068702,67.32824427,118.6259542,122.2900763,124.1221374])
# Yan P2X7 HEK ATP st 120s 1000 uM
t15 = np.array([0,0,7.328244275,25.64885496,32.97709924,53.58778626,79.23664122,94.80916031,107.1755725,118.6259542,120.9160305,122.2900763])

y10 = np.array([0,-0.1089494163,-0.2583657588,-0.2178988327,-0.4560311284,-0.7035019455,-0.1167315175,-0.0233463035,0.003112840467])
y11 = np.array([0,-0.03928571429,-0.05142857143,-0.05142857143,-0.04464285714,-0.04107142857,-0.002321428571,-0.00125])
y12 = np.array([0,-0.006428571429,-0.01303571429,-0.01428571429,-0.01345238095,-0.01255952381,-0.0008333333333,-0.000119047619])
y13 = np.array([0,-3.705357143,-3.869047619,-4.43452381,-4.419642857,-1.800595238,-0.2678571429,-0.08928571429])
y14 = np.array([0,-1.28125,-1.291666667,-2.833333333,-3.15625,-3.302083333,-3.322916667,-0.125,-0.03125])
y15 = np.array([0,-0.0505952381,-0.06845238095,-0.08035714286,-0.09523809524,-0.2083333333,-0.5863095238,-0.8392857143,-0.8988095238,-0.9077380952,0.03273809524,0.002976190476])

ax = plt.subplot(3,2,3)
ax2 = ax.twinx()
plt.tick_params(labelsize=12)
lns1 = ax.plot(t10,y10,label="K-H-ATP-15s-1mM")
lns2 = ax2.plot(t11,y11,'r-.',label="Y-H-ATP-120s-320uM")
lns3 = ax2.plot(t12,y12,'b-.',label="Y-H-ATP-120s-100uM")
lns4 = ax.plot(t13,y13,label="Y-H-ATP-40s-10mM")
lns5 = ax.plot(t14,y14,label="Y-H-ATP-120s-3.2mM")
lns6 = ax.plot(t15,y15,label="Y-H-ATP-120s-1mM")
ax.set_xlabel("time (s)",fontsize=12)
ax.set_ylabel("current (nA)",fontsize=12)
ax2.set_ylabel("current (nA)",fontsize=12)
lns = lns1 + lns2 + lns3+ lns6 + lns5 + lns4
labs = [l.get_label() for l in lns]
ax.legend(lns,labs,loc=0, fontsize=12)

# Khadra P2X4 HEK ATP st 63s 100 uM 1st pulse
t16 = np.array([0,0.75,6,11.25,18.75,30.75,75])
# Khadra P2X4 HEK ATP st 63s 100 uM 2nd pulse
t17 = np.array([0,1.2,3.3,6.3,8.7,33,63])
# Toulme P2X4 MG ATP st 30s 100 uM
t18 = np.array([0,0.35,1.975,3.85,6.35,10.4375,15.6875,23.625,30.375,30.5625,34.375])
# Egan P2X4 HEK ATP st 1s 30 uM
t19 = np.array([0,0.02702702703,0.06756756757,0.1081081081,0.4256756757,0.8108108108,0.9864864865,1.297297297,1.405405405,1.621621622,2.128378378])
# Garcia-Guzman hP2X4 HEK ATP 2.85s 50 uM
t20 = np.array([0,0.5813953488,0.9302325581,2.209302326,5.930232558,9.069767442,13.02325581,25.58139535])
# Toulme P2X4 MG ATP 29s 100 uM no Calcium
t21 = np.array([0,0.7019704433,1.600985222,2.795566502,4.224137931,6.4408867,10.09852217,15.39408867,21.67487685,30.01231527,30.20935961,35.6773399])
# Khakh P2X4 HEK ATP 190s 100 uM 
t23 = np.array([0,11.73913043,21.73913043,38.69565217,67.82608696,97.82608696,159.5652174])
# Khakh P2X4 HEK ATP 190s 100 um no Calcium
t24 = np.array([0,6.086956522,12.17391304,20,39.13043478,59.56521739,86.52173913,118.6956522,188.6956522])

y16 = np.array([0,-2.337552743,-0.7257383966,-0.3037974684,-0.1434599156,-0.08438818565,-0.01687763713])
y17 = np.array([0,-0.5518987342,-0.1181434599,-0.04556962025,-0.01687763713,-0.01687763713,0.005063291139])
y18 = 0.001*np.array([0,-716.2950257,-535.1629503,-402.7444254,-288.1646655,-178.3876501,-111.1492281,-57.6329331,-39.10806175,-2.744425386,0])
y19 = np.array([0,-0.4384530387,-0.5851933702,-0.5904972376,-0.4897237569,-0.4137016575,-0.3712707182,-0.05480662983,-0.01591160221,0.007071823204,0.008839779006])
y20 = 0.001*np.array([0,-499.58159,-499.58159,-389.1213389,-175.7322176,-105.4393305,-57.74058577,-10.041841])
y21 = 0.001*np.array([0,-276.9465649,-219.8473282,-167.0229008,-129.4656489,-90.6870229,-59.23664122,-34.80916031,-21.3740458,-14.35114504,-2.13740458,0])
y23 = np.array([0,-0.603557656,-0.5209413989,-0.3625935728,-0.2432589792,-0.1652325142,-0.1147448015])
y24 = np.array([0,-0.33,-0.1561153846,-0.08948076923,-0.04315384615,-0.02728846154,-0.01586538462,-0.01269230769,-0.1313653846])

plt.subplot(3,2,4)
plt.tick_params(labelsize=12)
#plt.plot(t16,y16,label="K-H-ATP-63s-100uM-1st")
plt.plot(t17,y17,'k-x',label="K-H-ATP-63s-100uM-2nd")
plt.plot(t18,y18,'r-',label="T-M-ATP-30s-100uM")
#plt.plot(t19,y19,label="E-H-ATP-1s-30uM")
#plt.plot(t20,y20,label="G-H-ATP-2.85s-50uM")
plt.plot(t21,y21,'r-.',label="T-M-ATP-29s-100uM-NoCa")
plt.plot(t23,y23,'b-',label="Kh-H-ATP-190s-100uM")
plt.plot(t24,y24,'b-.',label="Kh-H-ATP-190s-100uM-NoCa")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("current (nA)",fontsize=12)
plt.xlim(0,60)
plt.legend(loc=0,fontsize=12)

plt.subplot(3,2,5)
plt.tick_params(labelsize=12)
#plt.plot(t16,y16,label="K-H-ATP-63s-100uM-1st")
#plt.plot(t17,y17,label="K-H-ATP-63s-100uM-2nd")
plt.plot(t18,y18,label="T-M-ATP-30s-100uM")
#plt.plot(t19,y19,label="E-H-ATP-1s-30uM")
#plt.plot(t20,y20,label="G-H-ATP-2.85s-50uM")
plt.plot(t21,y21,label="T-M-ATP-29s-100uM-NoCa")
plt.plot(t23,y23,label="Kh-H-ATP-190s-100uM")
plt.plot(t24,y24,label="Kh-H-ATP-190s-100uM-NoCa")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("current (nA)",fontsize=12)
plt.legend(loc=0,fontsize=12)

plt.subplot(3,2,6)
plt.tick_params(labelsize=12)
#plt.plot(t16,y16,label="K-H-ATP-63s-100uM-1st")
plt.plot(t17,y17,label="K-H-ATP-63s-100uM-2nd")
plt.plot(t18,y18,label="T-M-ATP-30s-100uM")
#plt.plot(t19,y19,label="E-H-ATP-1s-30uM")
#plt.plot(t20,y20,label="G-H-ATP-2.85s-50uM")
#plt.plot(t21,y21,label="T-M-ATP-29s-100uM-NoCa")
plt.plot(t23,y23,label="Kh-H-ATP-190s-100uM")
#plt.plot(t24,y24,label="Kh-H-ATP-190s-100uM-NoCa")
plt.xlabel("time (s)",fontsize=12)
plt.ylabel("current (nA)",fontsize=12)
plt.legend(loc=0,fontsize=12)

plt.tight_layout()
