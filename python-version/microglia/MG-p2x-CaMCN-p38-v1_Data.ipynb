# %%
# Function for integreating ODE and displaying results
import scipy.integrate
from scipy.integrate import odeint
import numpy as np
import matplotlib.pylab as plt
import math
from math import exp
from scipy.interpolate import spline
import pickle as pk
# %matplotlib inline

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_10perboth.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_10perboth.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_10perboth.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_10perboth.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_10perboth.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_10perboth.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFareld1 = TNFarel1[init:final]
TNFareld2 = TNFarel2[init:final] 
TNFareld3 = TNFarel3[init:final] 
TNFareld4 = TNFarel4[init:final] 
TNFareld5 = TNFarel5[init:final] 
TNFareld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp381 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa1 = CaMAX1/(max(CaMAX1))*100
rCaMCN1 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT1 = NFATMAX1/(max(NFATMAX1))*100
rTNF1 = TNFMAX1/(max(TNFMAX1))*100

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_50perboth.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_50perboth.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_50perboth.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_50perboth.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_50perboth.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_50perboth.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFareld1 = TNFarel1[init:final]
TNFareld2 = TNFarel2[init:final] 
TNFareld3 = TNFarel3[init:final] 
TNFareld4 = TNFarel4[init:final] 
TNFareld5 = TNFarel5[init:final] 
TNFareld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp382 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa2 = CaMAX1/(max(CaMAX1))*100
rCaMCN2 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT2 = NFATMAX1/(max(NFATMAX1))*100
rTNF2 = TNFMAX1/(max(TNFMAX1))*100

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_50perp2x7.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_50perp2x7.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_50perp2x7.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_50perp2x7.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_50perp2x7.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_50perp2x7.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFareld1 = TNFarel1[init:final]
TNFareld2 = TNFarel2[init:final] 
TNFareld3 = TNFarel3[init:final] 
TNFareld4 = TNFarel4[init:final] 
TNFareld5 = TNFarel5[init:final] 
TNFareld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp383 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa3 = CaMAX1/(max(CaMAX1))*100
rCaMCN3 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT3 = NFATMAX1/(max(NFATMAX1))*100
rTNF3 = TNFMAX1/(max(TNFMAX1))*100

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_50perp2x4.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_50perp2x4.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_50perp2x4.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_50perp2x4.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_50perp2x4.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_50perp2x4.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFareld1 = TNFarel1[init:final]
TNFareld2 = TNFarel2[init:final] 
TNFareld3 = TNFarel3[init:final] 
TNFareld4 = TNFarel4[init:final] 
TNFareld5 = TNFarel5[init:final] 
TNFareld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp384 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa4 = CaMAX1/(max(CaMAX1))*100
rCaMCN4 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT4 = NFATMAX1/(max(NFATMAX1))*100
rTNF4 = TNFMAX1/(max(TNFMAX1))*100

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_1perp2x7.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_1perp2x7.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_1perp2x7.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_1perp2x7.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_1perp2x7.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_1perp2x7.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFareld1 = TNFarel1[init:final]
TNFareld2 = TNFarel2[init:final] 
TNFareld3 = TNFarel3[init:final] 
TNFareld4 = TNFarel4[init:final] 
TNFareld5 = TNFarel5[init:final] 
TNFareld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp385 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa5 = CaMAX1/(max(CaMAX1))*100
rCaMCN5 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT5 = NFATMAX1/(max(NFATMAX1))*100
rTNF5 = TNFMAX1/(max(TNFMAX1))*100

# %%
results1 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/1mMATP_01Hz_1perp2x4.p","rb"))
results2 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/05mMATP_01Hz_1perp2x4.p","rb"))
results3 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/02mMATP_01Hz_1perp2x4.p","rb"))
results4 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/01mMATP_01Hz_1perp2x4.p","rb"))
results5 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/001mMATP_01Hz_1perp2x4.p","rb"))
results6 = pk.load(open("/home/AD/bch265/myu1/microglia2018march/data/MG-p2x-CaMCN-p38-v1/00001mMATP_01Hz_1perp2x4.p","rb"))

Ca1 = results1[0]
Ca2 = results2[0]
Ca3 = results3[0]
Ca4 = results4[0]
Ca5 = results5[0]
Ca6 = results6[0]

CaMCN1 = results1[7]
CaMCN2 = results2[7]
CaMCN3 = results3[7]
CaMCN4 = results4[7]
CaMCN5 = results5[7]
CaMCN6 = results6[7]

NFATNn1 = results1[36]
NFATNn2 = results2[36]
NFATNn3 = results3[36]
NFATNn4 = results4[36]
NFATNn5 = results5[36]
NFATNn6 = results6[36]

TNFarel1 = results1[43]
TNFarel2 = results2[43]
TNFarel3 = results3[43]
TNFarel4 = results4[43]
TNFarel5 = results5[43]
TNFarel6 = results6[43]

pp381 = results1[44]
pp382 = results2[44]
pp383 = results3[44]
pp384 = results4[44]
pp385 = results5[44]
pp386 = results6[44]

init = 360000-110000
final = 360000

Cad1 = Ca1[init:final]
Cad2 = Ca2[init:final] 
Cad3 = Ca3[init:final] 
Cad4 = Ca4[init:final] 
Cad5 = Ca5[init:final]
Cad6 = Ca6[init:final]

CaMCNd1 = CaMCN1[init:final]
CaMCNd2 = CaMCN2[init:final] 
CaMCNd3 = CaMCN3[init:final] 
CaMCNd4 = CaMCN4[init:final] 
CaMCNd5 = CaMCN5[init:final]
CaMCNd6 = CaMCN6[init:final] 

NFATNnd1 = NFATNn1[init:final]
NFATNnd2 = NFATNn2[init:final] 
NFATNnd3 = NFATNn3[init:final] 
NFATNnd4 = NFATNn4[init:final] 
NFATNnd5 = NFATNn5[init:final]
NFATNnd6 = NFATNn6[init:final]

TNFreld1 = TNFarel1[init:final]
TNFreld2 = TNFarel2[init:final] 
TNFreld3 = TNFarel3[init:final] 
TNFreld4 = TNFarel4[init:final] 
TNFreld5 = TNFarel5[init:final] 
TNFreld6 = TNFarel6[init:final]

Camax1 = max(Cad1)
Camax2 = max(Cad2)
Camax3 = max(Cad3)
Camax4 = max(Cad4)
Camax5 = max(Cad5)
Camax6 = max(Cad6)

CaMCNmax1 = max(CaMCNd1)
CaMCNmax2 = max(CaMCNd2)
CaMCNmax3 = max(CaMCNd3)
CaMCNmax4 = max(CaMCNd4)
CaMCNmax5 = max(CaMCNd5)
CaMCNmax6 = max(CaMCNd6)

NFATmax1 = max(NFATNnd1)
NFATmax2 = max(NFATNnd2)
NFATmax3 = max(NFATNnd3)
NFATmax4 = max(NFATNnd4)
NFATmax5 = max(NFATNnd5)
NFATmax6 = max(NFATNnd6)

TNFmax1 = max(TNFareld1)
TNFmax2 = max(TNFareld2)
TNFmax3 = max(TNFareld3)
TNFmax4 = max(TNFareld4)
TNFmax5 = max(TNFareld5)
TNFmax6 = max(TNFareld6)

pp38d1 = pp381[init:final]
pp38d2 = pp382[init:final] 
pp38d3 = pp383[init:final] 
pp38d4 = pp384[init:final] 
pp38d5 = pp385[init:final]
pp38d6 = pp386[init:final]

pp38max1 = max(pp38d1)
pp38max2 = max(pp38d2)
pp38max3 = max(pp38d3)
pp38max4 = max(pp38d4)
pp38max5 = max(pp38d5)
pp38max6 = max(pp38d6)
pp38MAX1 = np.array([pp38max1,pp38max2,pp38max3,pp38max4,pp38max5,pp38max6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
rpp386 = pp38MAX1/(max(pp38MAX1))*100

CaMAX1 = np.array([Camax1,Camax2,Camax3,Camax4,Camax5,Camax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
CaMCNMAX1 = np.array([CaMCNmax1,CaMCNmax2,CaMCNmax3,CaMCNmax4,CaMCNmax5,CaMCNmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
NFATMAX1 = np.array([NFATmax1,NFATmax2,NFATmax3,NFATmax4,NFATmax5,NFATmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP
TNFMAX1 = np.array([TNFmax1,TNFmax2,TNFmax3,TNFmax4,TNFmax5,TNFmax6]) # 1, 0.5, 0.2, 0.1, 0.01, 0.0001 mM ATP

rCa6 = CaMAX1/(max(CaMAX1))*100
rCaMCN6 = CaMCNMAX1/(max(CaMCNMAX1))*100 
rNFAT6 = NFATMAX1/(max(NFATMAX1))*100
rTNF6 = TNFMAX1/(max(TNFMAX1))*100

# %%
plt.figure(figsize = (7,7))
atp = np.array([1,0.5,0.2,0.1,0.01,0.0001])
plt.tick_params(labelsize=12)
plt.semilogx(atp,rCa1,'g--x',label="Control")
plt.semilogx(atp,rCa2,'k--x',label="x5 on Both")
plt.semilogx(atp,rCa3,'b--x',label="x5 on P7")
plt.semilogx(atp,rCa4,'m--x',label="x5 on P4")
plt.semilogx(atp,rCa5,'c--x',label="x0.1 on P7")
plt.semilogx(atp,rCa6,'r--x',label="x0.1 on P7")
plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP (mM)",fontsize=15)
plt.ylabel("$[Ca_{2+}]_{i}$ (% of max)",fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig("LogRelCaMaxAllConditions.png")

# %%
plt.figure(figsize = (7,7))
atp = np.array([1,0.5,0.2,0.1,0.01,0.0001])
plt.tick_params(labelsize=12)
plt.semilogx(atp,rCaMCN1,'g--x',label="Control")
plt.semilogx(atp,rCaMCN2,'k--x',label="x5 on Both",linewidth=3)
plt.semilogx(atp,rCaMCN3,'b--x',label="x5 on P7")
plt.semilogx(atp,rCaMCN4,'m--x',label="x5 on P4")
plt.semilogx(atp,rCaMCN5,'c--x',label="x0.1 on P7")
plt.semilogx(atp,rCaMCN6,'r--x',label="x0.1 on P7")
plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP (mM)",fontsize=15)
plt.ylabel("$[CaM-CN]_{i}$ (% of max)",fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig("LogRelCaMCNMaxAllConditions.png")

# %%
plt.figure(figsize = (7,7))
atp = np.array([1,0.5,0.2,0.1,0.01,0.0001])
plt.tick_params(labelsize=12)
plt.semilogx(atp,rNFAT1,'g--x',label="Control")
plt.semilogx(atp,rNFAT2,'k--x',label="x5 on Both",linewidth=3)
plt.semilogx(atp,rNFAT3,'b--x',label="x5 on P7")
plt.semilogx(atp,rNFAT4,'m--x',label="x5 on P4")
plt.semilogx(atp,rNFAT5,'c--x',label="x0.1 on P7")
plt.semilogx(atp,rNFAT6,'r--x',label="x0.1 on P7")
plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP (mM)",fontsize=15)
plt.ylabel("$[NFATN]_{n}$ (% of max)",fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig("LogRelNFATMaxAllConditions.png")

# %%
plt.figure(figsize = (7,7))
atp = np.array([1,0.5,0.2,0.1,0.01,0.0001])
plt.tick_params(labelsize=12)
plt.semilogx(atp,rpp381,'g--x',label="Control")
plt.semilogx(atp,rpp382,'k--x',label="x5 on Both")
plt.semilogx(atp,rpp383,'b--x',label="x5 on P7")
plt.semilogx(atp,rpp384,'m--x',label="x5 on P4")
plt.semilogx(atp,rpp385,'c--x',label="x0.1 on P7")
plt.semilogx(atp,rpp386,'r--x',label="x0.1 on P7")
plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP (mM)",fontsize=15)
plt.ylabel("p-p38 (% of max)",fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig("LogRelpp38MaxAllConditions.png")

# %%
plt.figure(figsize = (7,7))
atp = np.array([1,0.5,0.2,0.1,0.01,0.0001])
plt.tick_params(labelsize=12)
plt.semilogx(atp,rTNF1,'g--x',label="Control")
plt.semilogx(atp,rTNF2,'k--x',label="x5 on Both")
plt.semilogx(atp,rTNF3,'b--x',label="x5 on P7")
plt.semilogx(atp,rTNF4,'m--x',label="x5 on P4")
plt.semilogx(atp,rTNF5,'c--x',label="x0.1 on P7")
plt.semilogx(atp,rTNF6,'r--x',label="x0.1 on P7")
plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP (mM)",fontsize=15)
plt.ylabel("TNFa released (% of max)",fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig("LogRelTNFMaxAllConditions.png")
