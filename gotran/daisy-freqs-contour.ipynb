# %%
# routlines for analyzing odes
# %matplotlib inline
import matplotlib.pylab as plto 
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/pkh-code/fitting')
import analyzeGotran as ao

import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
data11 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.001mMATPnew_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.01mMATPnew_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.1mMATPnew_cat.pickle")
data14 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_1mMATPnew_cat.pickle")

data21 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle")
data22 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle")
data23 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle")
data24 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle")

data31 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.001mMATPnew_cat.pickle")
data32 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.01mMATPnew_cat.pickle")
data33 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.1mMATPnew_cat.pickle")
data34 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_1mMATPnew_cat.pickle")

data41 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.001mMATPnew_cat.pickle")
data42 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.01mMATPnew_cat.pickle")
data43 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.1mMATPnew_cat.pickle")
data44 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st50rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data51 = ao.readPickle("/home/AD/bch265/Data_storage/50st900rsMG_0.001mMATPnew_cat.pickle")
data52 = ao.readPickle("/home/AD/bch265/Data_storage/50st900rsMG_0.01mMATPnew_cat.pickle")
data53 = ao.readPickle("/home/AD/bch265/Data_storage/50st900rsMG_0.1mMATPnew_cat.pickle")
data54 = ao.readPickle("/home/AD/bch265/Data_storage/50st900rsMG_1mMATPnew_cat.pickle")

data61 = ao.readPickle("/home/AD/bch265/Data_storage/150st800rsMG_0.001mMATPnew_cat.pickle")
data62 = ao.readPickle("/home/AD/bch265/Data_storage/150st800rsMG_0.01mMATPnew_cat.pickle")
data63 = ao.readPickle("/home/AD/bch265/Data_storage/150st800rsMG_0.1mMATPnew_cat.pickle")
data64 = ao.readPickle("/home/AD/bch265/Data_storage/150st800rsMG_1mMATPnew_cat.pickle")

data71 = ao.readPickle("/home/AD/bch265/Data_storage/450st500rsMG_0.001mMATPnew_cat.pickle")
data72 = ao.readPickle("/home/AD/bch265/Data_storage/450st500rsMG_0.01mMATPnew_cat.pickle")
data73 = ao.readPickle("/home/AD/bch265/Data_storage/450st500rsMG_0.1mMATPnew_cat.pickle")
data74 = ao.readPickle("/home/AD/bch265/Data_storage/450st500rsMG_1mMATPnew_cat.pickle")

data81 = ao.readPickle("/home/AD/bch265/Data_storage/900st50rsMG_0.001mMATPnew_cat.pickle")
data82 = ao.readPickle("/home/AD/bch265/Data_storage/900st50rsMG_0.01mMATPnew_cat.pickle")
data83 = ao.readPickle("/home/AD/bch265/Data_storage/900st50rsMG_0.1mMATPnew_cat.pickle")
data84 = ao.readPickle("/home/AD/bch265/Data_storage/900st50rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/50st900rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st900rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st900rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st900rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/150st800rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/150st800rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/150st800rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/150st800rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/450st500rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/450st500rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/450st500rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/450st500rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/900st50rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data91 = ao.readPickle("/home/AD/bch265/Data_storage/50st100rsMG_0.001mMATPnew_cat.pickle")
data92 = ao.readPickle("/home/AD/bch265/Data_storage/50st100rsMG_0.01mMATPnew_cat.pickle")
data93 = ao.readPickle("/home/AD/bch265/Data_storage/50st100rsMG_0.1mMATPnew_cat.pickle")
data94 = ao.readPickle("/home/AD/bch265/Data_storage/50st100rsMG_1mMATPnew_cat.pickle")

data01 = ao.readPickle("/home/AD/bch265/Data_storage/50st200rsMG_0.001mMATPnew_cat.pickle")
data02 = ao.readPickle("/home/AD/bch265/Data_storage/50st200rsMG_0.01mMATPnew_cat.pickle")
data03 = ao.readPickle("/home/AD/bch265/Data_storage/50st200rsMG_0.1mMATPnew_cat.pickle")
data04 = ao.readPickle("/home/AD/bch265/Data_storage/50st200rsMG_1mMATPnew_cat.pickle")

data10 = ao.readPickle("/home/AD/bch265/Data_storage/50st300rsMG_0.001mMATPnew_cat.pickle")
data20 = ao.readPickle("/home/AD/bch265/Data_storage/50st300rsMG_0.01mMATPnew_cat.pickle")
data30 = ao.readPickle("/home/AD/bch265/Data_storage/50st300rsMG_0.1mMATPnew_cat.pickle")
data40 = ao.readPickle("/home/AD/bch265/Data_storage/50st300rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/50st100rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st100rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st100rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st100rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st200rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st200rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st200rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st200rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st300rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st300rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st300rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st300rsMG_1mMATPnew_cat.pickle

# %%
data11.keys()
data12.keys()
data13.keys()
data14.keys()

data21.keys()
data22.keys()
data23.keys()
data24.keys()

data31.keys()
data32.keys()
data33.keys()
data34.keys()

data41.keys()
data42.keys()
data43.keys()
data44.keys()

data51.keys()
data52.keys()
data53.keys()
data54.keys()

data61.keys()
data62.keys()
data63.keys()
data64.keys()

data71.keys()
data72.keys()
data73.keys()
data74.keys()

data81.keys()
data82.keys()
data83.keys()
data84.keys()

data91.keys()
data92.keys()
data93.keys()
data94.keys()

data01.keys()
data02.keys()
data03.keys()
data04.keys()

data10.keys()
data20.keys()
data30.keys()
data40.keys()
# Out:
# ['s_idx', 'p_idx', 'j', 'p', 's', 'j_idx', 't']

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data51,stateLabel)
subData2 = ao.GetData(data61,stateLabel)
subData3 = ao.GetData(data71,stateLabel)
subData4 = ao.GetData(data81,stateLabel)

plt.figure(figsize=(7,8))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData1.t*1000-150,subData1.valsIdx,'b-',label="ST50/RS900")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(3000,3050)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData2.t*1000-150,subData2.valsIdx,'r-',label="ST150/RS800")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(3000,3150)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData3.t*1000-150,subData3.valsIdx,'g-',label="ST450/RS500")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(3000,3450)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot(subData4.t*1000-150,subData4.valsIdx,'k-',label="ST900/RS50")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(3000,3900)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew1mM.png")

# %%
stateLabel = "Cai"
subData51 = ao.GetData(data51,stateLabel)
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)

subData52 = ao.GetData(data52,stateLabel)
subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)

subData53 = ao.GetData(data53,stateLabel)
subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)

subData54 = ao.GetData(data54,stateLabel)
subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)

D51 = subData51.valsIdx[3200]
D52 = subData52.valsIdx[3200]
D53 = subData53.valsIdx[3200]
D54 = subData54.valsIdx[3200]

D61 = subData61.valsIdx[3300]
D62 = subData62.valsIdx[3300]
D63 = subData63.valsIdx[3300]
D64 = subData64.valsIdx[3300]

D71 = subData71.valsIdx[3600]
D72 = subData72.valsIdx[3600]
D73 = subData73.valsIdx[3600]
D74 = subData74.valsIdx[3600]

D81 = subData81.valsIdx[4050]
D82 = subData82.valsIdx[4050]
D83 = subData83.valsIdx[4050]
D84 = subData84.valsIdx[4050]

print np.array([[D51, D52, D53, D54], [D61, D62, D63, D64], [D71, D72, D73, D74], [D81, D82, D83, D84]])
# Out:
# [[ 0.14326171  0.15356277  0.16245797  0.31226608]
#  [ 0.1394732   0.15094029  0.1591781   0.26757278]
#  [ 0.13941233  0.14856883  0.15376791  0.26167386]
#  [ 0.1393419   0.14609531  0.14860826  0.2616689 ]]

# %%
stateLabel = "TNFa_release"
subData51 = ao.GetData(data51,stateLabel)
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)

subData52 = ao.GetData(data52,stateLabel)
subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)

subData53 = ao.GetData(data53,stateLabel)
subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)

subData54 = ao.GetData(data54,stateLabel)
subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)

D51 = subData51.valsIdx[3200]
D52 = subData52.valsIdx[3200]
D53 = subData53.valsIdx[3200]
D54 = subData54.valsIdx[3200]

D61 = subData61.valsIdx[3300]
D62 = subData62.valsIdx[3300]
D63 = subData63.valsIdx[3300]
D64 = subData64.valsIdx[3300]

D71 = subData71.valsIdx[3600]
D72 = subData72.valsIdx[3600]
D73 = subData73.valsIdx[3600]
D74 = subData74.valsIdx[3600]

D81 = subData81.valsIdx[4050]
D82 = subData82.valsIdx[4050]
D83 = subData83.valsIdx[4050]
D84 = subData84.valsIdx[4050]

print np.array([[D51, D52, D53, D54], [D61, D62, D63, D64], [D71, D72, D73, D74], [D81, D82, D83, D84]])
# Out:
# [[  0.26576881   0.27568106   0.28550895   0.53900927]
#  [  0.31433949   0.34418001   0.37087577   0.91537567]
#  [  0.54337586   0.69554471   0.81699458   3.59361902]
#  [  1.25513577   1.8119826    2.15642198  19.0728991 ]]

# %%
a = np.matrix('1 2; 3 4')
print a
# Out:
# [[1 2]
#  [3 4]]

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data44,stateLabel)
subData2 = ao.GetData(data94,stateLabel)
subData3 = ao.GetData(data04,stateLabel)
subData4 = ao.GetData(data40,stateLabel)

plt.figure(figsize=(7,8))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData1.t*1000,subData1.valsIdx,'b-',label="ST50/RS50")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(3750,3800)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData2.t*1000,subData2.valsIdx,'r-',label="ST50/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(3750,3800)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData3.t*1000,subData3.valsIdx,'g-',label="ST50/RS200")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(3750,3800)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot(subData4.t*1000,subData4.valsIdx,'k-',label="ST50/RS300")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(3750,3800)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqrexnew1mM.png")

# %%
stateLabel = "Cai"
subData41 = ao.GetData(data41,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData10 = ao.GetData(data10,stateLabel)

subData42 = ao.GetData(data42,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData20 = ao.GetData(data20,stateLabel)

subData43 = ao.GetData(data43,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData30 = ao.GetData(data30,stateLabel)

subData44 = ao.GetData(data44,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData40 = ao.GetData(data40,stateLabel)

D41 = subData41.valsIdx[3800]
D42 = subData42.valsIdx[3800]
D43 = subData43.valsIdx[3800]
D44 = subData44.valsIdx[3800]

D91 = subData91.valsIdx[3800]
D92 = subData92.valsIdx[3800]
D93 = subData93.valsIdx[3800]
D94 = subData94.valsIdx[3800]

D01 = subData01.valsIdx[3800]
D02 = subData02.valsIdx[3800]
D03 = subData03.valsIdx[3800]
D04 = subData04.valsIdx[3800]

D10 = subData10.valsIdx[3800]
D20 = subData20.valsIdx[3800]
D30 = subData30.valsIdx[3800]
D40 = subData40.valsIdx[3800]

print np.array([[D41, D42, D43, D44], [D91, D92, D93, D94], [D01, D02, D03, D04], [D10, D20, D30, D40]])
# Out:
# [[ 0.14008951  0.14860434  0.1537667   0.30656012]
#  [ 0.14153525  0.15114019  0.1584204   0.31221946]
#  [ 0.14228358  0.15217352  0.16012738  0.31233617]
#  [ 0.14270712  0.15271984  0.16099863  0.31235267]]

# %%
stateLabel = "TNFa_release"
subData41 = ao.GetData(data41,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData10 = ao.GetData(data10,stateLabel)

subData42 = ao.GetData(data42,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData20 = ao.GetData(data20,stateLabel)

subData43 = ao.GetData(data43,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData30 = ao.GetData(data30,stateLabel)

subData44 = ao.GetData(data44,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData40 = ao.GetData(data40,stateLabel)

D41 = subData41.valsIdx[3800]
D42 = subData42.valsIdx[3800]
D43 = subData43.valsIdx[3800]
D44 = subData44.valsIdx[3800]

D91 = subData91.valsIdx[3800]
D92 = subData92.valsIdx[3800]
D93 = subData93.valsIdx[3800]
D94 = subData94.valsIdx[3800]

D01 = subData01.valsIdx[3800]
D02 = subData02.valsIdx[3800]
D03 = subData03.valsIdx[3800]
D04 = subData04.valsIdx[3800]

D10 = subData10.valsIdx[3800]
D20 = subData20.valsIdx[3800]
D30 = subData30.valsIdx[3800]
D40 = subData40.valsIdx[3800]

print np.array([[D41, D42, D43, D44], [D91, D92, D93, D94], [D01, D02, D03, D04], [D10, D20, D30, D40]])
# Out:
# [[  0.88051536   1.10266863   1.29859071  13.35844033]
#  [  0.46802479   0.51749071   0.56421768   2.33939432]
#  [  0.38523414   0.41435549   0.44235509   1.31089482]
#  [  0.34742002   0.36910268   0.39015709   0.99533476]]

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data11,stateLabel)
subData2 = ao.GetData(data21,stateLabel)
subData3 = ao.GetData(data31,stateLabel)
subData4 = ao.GetData(data41,stateLabel)

plt.figure(figsize=(7,8))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData1.t*1000,subData1.valsIdx,'b-',label="ST10/RS10")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.135,0.14)
plt.xlim(3800,4200)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData2.t*1000,subData2.valsIdx,'r-',label="ST20/RS20")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.12,0.145)
plt.xlim(3800,4200)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData3.t*1000,subData3.valsIdx,'g-',label="ST40/RS40")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.10,0.16)
plt.xlim(3800,4200)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot(subData4.t*1000-3800,subData4.valsIdx,'k-',label="ST50/RS50")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.10,0.16)
plt.xlim(0,400)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew0.001mM.png")

# %%
stateLabel = "Cai"
subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)

D11 = subData11.valsIdx[4100]
D12 = subData12.valsIdx[4100]
D13 = subData13.valsIdx[4100]
D14 = subData14.valsIdx[4100]

D21 = subData21.valsIdx[4100]
D22 = subData22.valsIdx[4100]
D23 = subData23.valsIdx[4100]
D24 = subData24.valsIdx[4100]

D31 = subData31.valsIdx[4100]
D32 = subData32.valsIdx[4100]
D33 = subData33.valsIdx[4100]
D34 = subData34.valsIdx[4100]

D41 = subData41.valsIdx[4100]
D42 = subData42.valsIdx[4100]
D43 = subData43.valsIdx[4100]
D44 = subData44.valsIdx[4100]

print np.array([[D11, D12, D13, D14], [D21, D22, D23, D24], [D31, D32, D33, D34], [D41, D42, D43, D44]])
# Out:
# [[ 0.13969524  0.14487541  0.14822742  0.3233225 ]
#  [ 0.1417985   0.14770511  0.15157189  0.32553156]
#  [ 0.1408238   0.14866539  0.15357005  0.31378279]
#  [ 0.14009289  0.14858296  0.15372258  0.30660833]]

# %%
stateLabel = "TNFa_release"
subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)

D11 = subData11.valsIdx[4100]
D12 = subData12.valsIdx[4100]
D13 = subData13.valsIdx[4100]
D14 = subData14.valsIdx[4100]

D21 = subData21.valsIdx[4100]
D22 = subData22.valsIdx[4100]
D23 = subData23.valsIdx[4100]
D24 = subData24.valsIdx[4100]

D31 = subData31.valsIdx[4100]
D32 = subData32.valsIdx[4100]
D33 = subData33.valsIdx[4100]
D34 = subData34.valsIdx[4100]

D41 = subData41.valsIdx[4100]
D42 = subData42.valsIdx[4100]
D43 = subData43.valsIdx[4100]
D44 = subData44.valsIdx[4100]

print np.array([[D11, D12, D13, D14], [D21, D22, D23, D24], [D31, D32, D33, D34], [D41, D42, D43, D44]])
# Out:
# [[  1.33040684   1.67344312   1.95670484  24.3012215 ]
#  [  1.24035163   1.55017527   1.8243886   22.25763708]
#  [  1.0662577    1.336686     1.57455089  17.50925334]
#  [  0.9845635    1.23940057   1.46231481  15.19830955]]

# %%
stateLabel = "Cai"

subData1 = ao.GetData(data54,stateLabel)
subData2 = ao.GetData(data64,stateLabel)
subData3 = ao.GetData(data74,stateLabel)
subData4 = ao.GetData(data84,stateLabel)

# %%
ca1 = max(subData1.valsIdx[2000:4000])
ca2 = max(subData2.valsIdx[2000:4000])
ca3 = max(subData3.valsIdx[2000:4000])
ca4 = max(subData4.valsIdx[2000:4000])
ca5 = max(subData5.valsIdx[2000:4000])

cas = np.array([ca1,ca2,ca3,ca4,ca5])
camax = max(cas)

car = cas/camax

rest = np.array([50,100,200,300,900])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(rest,car,'k--s',label="ST50 - 1 mM ATP")
plt.xlabel("Resting term (sec)",fontsize=15)
plt.ylabel("Relative [Ca] (fraction of max)")

plt.ylim(0.4,1.02)
plt.xlim(0,920)

plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqrelplot.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)

tnfa1 = max(subData1.valsIdx[2000:4000])
tnfa2 = max(subData2.valsIdx[2000:4000])
tnfa3 = max(subData3.valsIdx[2000:4000])
tnfa4 = max(subData4.valsIdx[2000:4000])
tnfa5 = max(subData5.valsIdx[2000:4000])

tnfas = np.array([tnfa1,tnfa2,tnfa3,tnfa4,tnfa5])
tnfamax = max(tnfas)

tnfar = tnfas/tnfamax

rest = np.array([50,100,200,300,900])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(rest,tnfar,'k--s',label="ST50 - 1 mM ATP")
plt.xlabel("Resting term (sec)",fontsize=15)
plt.ylabel("Relative [tnfa] (fraction of max)")

plt.ylim(0.2,1.02)
plt.xlim(0,920)

plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfavsfreqrelplot.png")
