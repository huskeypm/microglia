# %%
# routlines for analyzing odes
# %matplotlib inline
import matplotlib.pylab as plto 
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/pkh-code/fitting')
import analyzeGotran as ao

import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
data110 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.001mMATPnew_cat.pickle")
data120 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.01mMATPnew_cat.pickle")
data130 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.1mMATPnew_cat.pickle")
data140 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_1mMATPnew_cat.pickle

# %%
data11 = ao.readPickle("/home/AD/bch265/Data_storage/5st5rsMG_0.001mMATPnew_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/5st5rsMG_0.01mMATPnew_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/5st5rsMG_0.1mMATPnew_cat.pickle")
data14 = ao.readPickle("/home/AD/bch265/Data_storage/5st5rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/5st5rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st5rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st5rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st5rsMG_1mMATPnew_cat.pickle

# %%
data21 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle")
data22 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle")
data23 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle")
data24 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle")

data31 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.001mMATPnew_cat.pickle")
data32 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.01mMATPnew_cat.pickle")
data33 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_0.1mMATPnew_cat.pickle")
data34 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_1mMATPnew_cat.pickle")

#data41 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.001mMATPnew_cat.pickle")
#data42 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.01mMATPnew_cat.pickle")
#data43 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_0.1mMATPnew_cat.pickle")
#data44 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_1mMATPnew_cat.pickle

# %%
data51 = ao.readPickle("/home/AD/bch265/Data_storage/1st100rsMG_0.001mMATPnew_cat.pickle")
data52 = ao.readPickle("/home/AD/bch265/Data_storage/1st100rsMG_0.01mMATPnew_cat.pickle")
data53 = ao.readPickle("/home/AD/bch265/Data_storage/1st100rsMG_0.1mMATPnew_cat.pickle")
data54 = ao.readPickle("/home/AD/bch265/Data_storage/1st100rsMG_1mMATPnew_cat.pickle")

data61 = ao.readPickle("/home/AD/bch265/Data_storage/5st100rsMG_0.001mMATPnew_cat.pickle")
data62 = ao.readPickle("/home/AD/bch265/Data_storage/5st100rsMG_0.01mMATPnew_cat.pickle")
data63 = ao.readPickle("/home/AD/bch265/Data_storage/5st100rsMG_0.1mMATPnew_cat.pickle")
data64 = ao.readPickle("/home/AD/bch265/Data_storage/5st100rsMG_1mMATPnew_cat.pickle")

data71 = ao.readPickle("/home/AD/bch265/Data_storage/25st100rsMG_0.001mMATPnew_cat.pickle")
data72 = ao.readPickle("/home/AD/bch265/Data_storage/25st100rsMG_0.01mMATPnew_cat.pickle")
data73 = ao.readPickle("/home/AD/bch265/Data_storage/25st100rsMG_0.1mMATPnew_cat.pickle")
data74 = ao.readPickle("/home/AD/bch265/Data_storage/25st100rsMG_1mMATPnew_cat.pickle")

data81 = ao.readPickle("/home/AD/bch265/Data_storage/100st100rsMG_0.001mMATPnew_cat.pickle")
data82 = ao.readPickle("/home/AD/bch265/Data_storage/100st100rsMG_0.01mMATPnew_cat.pickle")
data83 = ao.readPickle("/home/AD/bch265/Data_storage/100st100rsMG_0.1mMATPnew_cat.pickle")
data84 = ao.readPickle("/home/AD/bch265/Data_storage/100st100rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/1st100rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st100rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st100rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st100rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st100rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st100rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st100rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st100rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/25st100rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/25st100rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/25st100rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/25st100rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/100st100rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data91 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle")
data92 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle")
data93 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle")
data94 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle")

data1a = ao.readPickle("/home/AD/bch265/Data_storage/20st80rsMG_0.001mMATPnew_cat.pickle")
data2a = ao.readPickle("/home/AD/bch265/Data_storage/20st80rsMG_0.01mMATPnew_cat.pickle")
data3a = ao.readPickle("/home/AD/bch265/Data_storage/20st80rsMG_0.1mMATPnew_cat.pickle")
data4a = ao.readPickle("/home/AD/bch265/Data_storage/20st80rsMG_1mMATPnew_cat.pickle")

data01 = ao.readPickle("/home/AD/bch265/Data_storage/20st120rsMG_0.001mMATPnew_cat.pickle")
data02 = ao.readPickle("/home/AD/bch265/Data_storage/20st120rsMG_0.01mMATPnew_cat.pickle")
data03 = ao.readPickle("/home/AD/bch265/Data_storage/20st120rsMG_0.1mMATPnew_cat.pickle")
data04 = ao.readPickle("/home/AD/bch265/Data_storage/20st120rsMG_1mMATPnew_cat.pickle")

data10 = ao.readPickle("/home/AD/bch265/Data_storage/20st160rsMG_0.001mMATPnew_cat.pickle")
data20 = ao.readPickle("/home/AD/bch265/Data_storage/20st160rsMG_0.01mMATPnew_cat.pickle")
data30 = ao.readPickle("/home/AD/bch265/Data_storage/20st160rsMG_0.1mMATPnew_cat.pickle")
data40 = ao.readPickle("/home/AD/bch265/Data_storage/20st160rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st80rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st80rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st80rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st80rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st120rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st120rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st120rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st120rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st160rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data4a = ao.readPickle("/home/AD/bch265/Data_storage/20st80rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/20st80rsMG_1mMATPnew_cat.pickle

# %%
data11.keys()
data12.keys()
data13.keys()
data14.keys()

data21.keys()
data22.keys()
data23.keys()
data24.keys()

data31.keys()
data32.keys()
data33.keys()
data34.keys()

data41.keys()
data42.keys()
data43.keys()
data44.keys()

data51.keys()
data52.keys()
data53.keys()
data54.keys()

data61.keys()
data62.keys()
data63.keys()
data64.keys()

data71.keys()
data72.keys()
data73.keys()
data74.keys()

data81.keys()
data82.keys()
data83.keys()
data84.keys()

data91.keys()
data92.keys()
data93.keys()
data94.keys()

data01.keys()
data02.keys()
data03.keys()
data04.keys()

data10.keys()
data20.keys()
data30.keys()
data40.keys()
# Out:
# ['s_idx', 'p_idx', 'j', 'p', 's', 'j_idx', 't']

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data54,stateLabel)
subData2 = ao.GetData(data64,stateLabel)
subData3 = ao.GetData(data74,stateLabel)
subData4 = ao.GetData(data84,stateLabel)

plt.figure(figsize=(7,8))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot((subData1.t-1000)/60,subData1.valsIdx,'b-',label="ST1/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(0,5)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot((subData2.t-1000)/60,subData2.valsIdx,'r-',label="ST5/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(0,5)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot((subData3.t-1000)/60,subData3.valsIdx,'g-',label="ST25/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(0,5)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot((subData4.t-1000)/60,subData4.valsIdx,'k-',label="ST100/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
plt.xlim(0,5)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew1mM.png")

# %%
stateLabel = "Cai"
subData51 = ao.GetData(data51,stateLabel)
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)

subData52 = ao.GetData(data52,stateLabel)
subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)

subData53 = ao.GetData(data53,stateLabel)
subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)

subData54 = ao.GetData(data54,stateLabel)
subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)

D51 = (max(subData51.valsIdx[1000:1500])+min(subData51.valsIdx[1000:1500]))/2
D52 = (max(subData52.valsIdx[1000:1500])+min(subData52.valsIdx[1000:1500]))/2
D53 = (max(subData53.valsIdx[1000:1500])+min(subData53.valsIdx[1000:1500]))/2
D54 = (max(subData54.valsIdx[1000:1500])+min(subData54.valsIdx[1000:1500]))/2

D61 = (max(subData61.valsIdx[1000:1500])+min(subData61.valsIdx[1000:1500]))/2
D62 = (max(subData62.valsIdx[1000:1500])+min(subData62.valsIdx[1000:1500]))/2
D63 = (max(subData63.valsIdx[1000:1500])+min(subData63.valsIdx[1000:1500]))/2
D64 = (max(subData64.valsIdx[1000:1500])+min(subData64.valsIdx[1000:1500]))/2

D71 = (max(subData71.valsIdx[1000:1500])+min(subData71.valsIdx[1000:1500]))/2
D72 = (max(subData72.valsIdx[1000:1500])+min(subData72.valsIdx[1000:1500]))/2
D73 = (max(subData73.valsIdx[1000:1500])+min(subData73.valsIdx[1000:1500]))/2
D74 = (max(subData74.valsIdx[1000:1500])+min(subData74.valsIdx[1000:1500]))/2

D81 = (max(subData81.valsIdx[1000:1500])+min(subData81.valsIdx[1000:1500]))/2
D82 = (max(subData82.valsIdx[1000:1500])+min(subData82.valsIdx[1000:1500]))/2
D83 = (max(subData83.valsIdx[1000:1500])+min(subData83.valsIdx[1000:1500]))/2
D84 = (max(subData84.valsIdx[1000:1500])+min(subData84.valsIdx[1000:1500]))/2

print np.array([[D51, D52, D53, D54], [D61, D62, D63, D64], [D71, D72, D73, D74], [D81, D82, D83, D84]])
# Out:
# [[ 0.11528637  0.11518936  0.1151821   0.12559291]
#  [ 0.11491903  0.11484883  0.11484657  0.12698148]
#  [ 0.11520069  0.11515961  0.11515862  0.1271345 ]
#  [ 0.11352147  0.11348236  0.11346233  0.12612269]]

# %%
stateLabel = "TNFa_release"
subData51 = ao.GetData(data51,stateLabel)
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)

subData52 = ao.GetData(data52,stateLabel)
subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)

subData53 = ao.GetData(data53,stateLabel)
subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)

subData54 = ao.GetData(data54,stateLabel)
subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)

D51 = subData51.valsIdx[3600]
D52 = subData52.valsIdx[3600]
D53 = subData53.valsIdx[3600]
D54 = subData54.valsIdx[3600]

D61 = subData61.valsIdx[3600]
D62 = subData62.valsIdx[3600]
D63 = subData63.valsIdx[3600]
D64 = subData64.valsIdx[3600]

D71 = subData71.valsIdx[3600]
D72 = subData72.valsIdx[3600]
D73 = subData73.valsIdx[3600]
D74 = subData74.valsIdx[3600]

D81 = subData81.valsIdx[3600]
D82 = subData82.valsIdx[3600]
D83 = subData83.valsIdx[3600]
D84 = subData84.valsIdx[3600]

print np.array([[D51, D52, D53, D54], [D61, D62, D63, D64], [D71, D72, D73, D74], [D81, D82, D83, D84]])
# Out:
# [[  8.48931767   8.49335989   8.49424973   8.58650787]
#  [  8.50340677   8.50743679   8.50918681   8.91786637]
#  [  8.39264939   8.40442309   8.41706366   9.61860383]
#  [  8.08413955   8.12363715   8.15807116  10.59080545]]

# %%
stateLabel = "NFATNn"
subData1 = ao.GetData(data93,stateLabel)
subData2 = ao.GetData(data4a,stateLabel)
subData3 = ao.GetData(data03,stateLabel)
subData4 = ao.GetData(data40,stateLabel)

plt.figure(figsize=(7,8))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData1.t,subData1.valsIdx,'b-',label="ST1/RS1")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(0,250)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData2.t,subData2.valsIdx,'r-',label="ST1/RS10")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(0,250)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData3.t,subData3.valsIdx,'g-',label="ST1/RS20")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(0,250)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot(subData4.t,subData4.valsIdx,'k-',label="ST1/RS30")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
#plt.ylim(0.05,0.25)
#plt.xlim(3560,3600)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqrexnew1mM.png")

# %%
center = 3000
a = (subData1.valsIdx[center+50]-subData1.valsIdx[center])/50
b = (subData1.valsIdx[center]-subData1.valsIdx[center-50])/50
print a, b
# Out:
# 8.01019187736e-05 8.4209727175e-05

# %%
stateLabel = "Cai"

subData91 = ao.GetData(data91,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData10 = ao.GetData(data10,stateLabel)

subData92 = ao.GetData(data92,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData20 = ao.GetData(data20,stateLabel)

subData93 = ao.GetData(data93,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData30 = ao.GetData(data30,stateLabel)

subData94 = ao.GetData(data94,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData40 = ao.GetData(data40,stateLabel)

D0 = min(subData91.valsIdx[90:100])



D91 = (max(subData91.valsIdx[1000:1500])+min(subData91.valsIdx[1000:1500]))/2
D92 = (max(subData92.valsIdx[1000:1500])+min(subData92.valsIdx[1000:1500]))/2
D93 = (max(subData93.valsIdx[1000:1500])+min(subData93.valsIdx[1000:1500]))/2
D94 = (max(subData94.valsIdx[1000:1500])+min(subData94.valsIdx[1000:1500]))/2

D1a = (max(subData1a.valsIdx[1000:1500])+min(subData1a.valsIdx[1000:1500]))/2
D2a = (max(subData2a.valsIdx[1000:1500])+min(subData2a.valsIdx[1000:1500]))/2
D3a = (max(subData3a.valsIdx[1000:1500])+min(subData3a.valsIdx[1000:1500]))/2
D4a = (max(subData4a.valsIdx[1000:1500])+min(subData4a.valsIdx[1000:1500]))/2

D01 = (max(subData01.valsIdx[1000:1500])+min(subData01.valsIdx[1000:1500]))/2
D02 = (max(subData02.valsIdx[1000:1500])+min(subData02.valsIdx[1000:1500]))/2
D03 = (max(subData03.valsIdx[1000:1500])+min(subData03.valsIdx[1000:1500]))/2
D04 = (max(subData04.valsIdx[1000:1500])+min(subData04.valsIdx[1000:1500]))/2

D10 = (max(subData10.valsIdx[1000:1500])+min(subData10.valsIdx[1000:1500]))/2
D20 = (max(subData20.valsIdx[1000:1500])+min(subData20.valsIdx[1000:1500]))/2
D30 = (max(subData30.valsIdx[1000:1500])+min(subData30.valsIdx[1000:1500]))/2
D40 = (max(subData40.valsIdx[1000:1500])+min(subData40.valsIdx[1000:1500]))/2

print np.array([[D0, D91, D92, D93, D94], [D0, D1a, D2a, D3a, D4a], [D0, D01, D02, D03, D04]])
# Out:
# [[ 0.10028357  0.10511069  0.10514764  0.10519881  0.12215546]
#  [ 0.10028357  0.11454013  0.11461022  0.11463483  0.10122161]
#  [ 0.10028357  0.09995533  0.09995533  0.09995533  0.10122161]]

# %%
stateLabel = "TNFa_release"

#subData110 = ao.GetData(data110,stateLabel)
#subData120 = ao.GetData(data120,stateLabel)
#subData130 = ao.GetData(data130,stateLabel)
#subData140 = ao.GetData(data140,stateLabel)

subData91 = ao.GetData(data91,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData10 = ao.GetData(data10,stateLabel)

subData92 = ao.GetData(data92,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData20 = ao.GetData(data20,stateLabel)

subData93 = ao.GetData(data93,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData30 = ao.GetData(data30,stateLabel)

subData94 = ao.GetData(data94,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData40 = ao.GetData(data40,stateLabel)

D0 = max(subData91.valsIdx[90:95])

#D110 = subData110.valsIdx[3600]
#D120 = subData120.valsIdx[3600]
#D130 = subData130.valsIdx[3600]
#D140 = subData140.valsIdx[3600]

D91 = subData91.valsIdx[3600]
D92 = subData92.valsIdx[3600]
D93 = subData93.valsIdx[3600]
D94 = subData94.valsIdx[3600]

D1a = subData1a.valsIdx[3600]
D2a = subData2a.valsIdx[3600]
D3a = subData3a.valsIdx[3600]
D4a = subData4a.valsIdx[3600]

D01 = subData01.valsIdx[3600]
D02 = subData02.valsIdx[3600]
D03 = subData03.valsIdx[3600]
D04 = subData04.valsIdx[3600]

D10 = subData10.valsIdx[3600]
D20 = subData20.valsIdx[3600]
D30 = subData30.valsIdx[3600]
D40 = subData40.valsIdx[3600]

print np.array([[D0, D91, D92, D93, D94], [D0, D1a, D2a, D3a, D4a], [D0, D01, D02, D03, D04]])
# Out:
# [[  5.49393864   8.82417159   8.8640114    8.90122197  14.13987635]
#  [  5.49393864   6.51618472   6.52118372   6.52658377   6.88862852]
#  [  5.49393864   6.49373325   6.49838073   6.5033743    6.87430036]]

# %%
stateLabel = "Cai"
subData0 = ao.GetData(data140,stateLabel)
subData1 = ao.GetData(data14,stateLabel)
subData2 = ao.GetData(data24,stateLabel)
subData3 = ao.GetData(data34,stateLabel)

plt.figure(figsize=(7,10))
ax = plt.subplot(5,1,1)
ax.tick_params(labelsize=12)
ax.plot((subData0.t-1000)/60,subData0.valsIdx,'b-',label="ST1/RS1")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.115,0.135)
plt.xlim(0,3)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,2)
ax.tick_params(labelsize=12)
ax.plot((subData1.t-1000)/60,subData1.valsIdx,'r-',label="ST5/RS5")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.1,0.15)
plt.xlim(0,3)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,3)
ax.tick_params(labelsize=12)
ax.plot((subData2.t-1000)/60,subData2.valsIdx,'g-',label="ST20/RS20")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.1,0.15)
plt.xlim(0,3)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,4)
ax.tick_params(labelsize=12)
ax.plot((subData3.t-1000)/60,subData3.valsIdx,'k-',label="ST40/RS40")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.1,0.15)
plt.xlim(0,3)
ax.set_xlabel("time (min)",fontsize=15)
plt.tight_layout()


plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew1mM.png")

# %%
stateLabel = "Cai"

subData110 = ao.GetData(data110,stateLabel)
subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)

subData120 = ao.GetData(data120,stateLabel)
subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)

subData130 = ao.GetData(data130,stateLabel)
subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)

subData140 = ao.GetData(data140,stateLabel)
subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)

D110 = (max(subData110.valsIdx[1000:1500])+min(subData110.valsIdx[1000:1500]))/2
D120 = (max(subData120.valsIdx[1000:1500])+min(subData120.valsIdx[1000:1500]))/2
D130 = (max(subData130.valsIdx[1000:1500])+min(subData130.valsIdx[1000:1500]))/2
D140 = (max(subData140.valsIdx[1000:1500])+min(subData140.valsIdx[1000:1500]))/2

D11 = (max(subData11.valsIdx[1000:1500])+min(subData11.valsIdx[1000:1500]))/2
D12 = (max(subData12.valsIdx[1000:1500])+min(subData12.valsIdx[1000:1500]))/2
D13 = (max(subData13.valsIdx[1000:1500])+min(subData13.valsIdx[1000:1500]))/2
D14 = (max(subData14.valsIdx[1000:1500])+min(subData14.valsIdx[1000:1500]))/2

D21 = (max(subData21.valsIdx[1000:1500])+min(subData21.valsIdx[1000:1500]))/2
D22 = (max(subData22.valsIdx[1000:1500])+min(subData22.valsIdx[1000:1500]))/2
D23 = (max(subData23.valsIdx[1000:1500])+min(subData23.valsIdx[1000:1500]))/2
D24 = (max(subData24.valsIdx[1000:1500])+min(subData24.valsIdx[1000:1500]))/2

D31 = (max(subData31.valsIdx[1000:1500])+min(subData31.valsIdx[1000:1500]))/2
D32 = (max(subData32.valsIdx[1000:1500])+min(subData32.valsIdx[1000:1500]))/2
D33 = (max(subData33.valsIdx[1000:1500])+min(subData33.valsIdx[1000:1500]))/2
D34 = (max(subData34.valsIdx[1000:1500])+min(subData34.valsIdx[1000:1500]))/2

D41 = (max(subData41.valsIdx[1000:1500])+min(subData41.valsIdx[1000:1500]))/2
D42 = (max(subData42.valsIdx[1000:1500])+min(subData42.valsIdx[1000:1500]))/2
D43 = (max(subData43.valsIdx[1000:1500])+min(subData43.valsIdx[1000:1500]))/2
D44 = (max(subData44.valsIdx[1000:1500])+min(subData44.valsIdx[1000:1500]))/2

print np.array([[D110, D120, D130, D140], [D11, D12, D13, D14], [D21, D22, D23, D24], [D31, D32, D33, D34]])
# Out:
# [[ 0.10509987  0.10531223  0.10549872  0.12468606]
#  [ 0.10451035  0.10466136  0.10482475  0.12291497]
#  [ 0.10511069  0.10514764  0.10519881  0.12215546]
#  [ 0.10788651  0.10788165  0.10789896  0.12296528]]

# %%
stateLabel = "TNFa_release"
subData110 = ao.GetData(data110,stateLabel)
subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)

subData120 = ao.GetData(data120,stateLabel)
subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)

subData130 = ao.GetData(data130,stateLabel)
subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)

subData140 = ao.GetData(data140,stateLabel)
subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)

D110 = subData110.valsIdx[1200]
D120 = subData120.valsIdx[1200]
D130 = subData130.valsIdx[1200]
D140 = subData140.valsIdx[1200]

D11 = subData11.valsIdx[1200]
D12 = subData12.valsIdx[1200]
D13 = subData13.valsIdx[1200]
D14 = subData14.valsIdx[1200]

D21 = subData21.valsIdx[1200]
D22 = subData22.valsIdx[1200]
D23 = subData23.valsIdx[1200]
D24 = subData24.valsIdx[1200]

D31 = subData31.valsIdx[1200]
D32 = subData32.valsIdx[1200]
D33 = subData33.valsIdx[1200]
D34 = subData34.valsIdx[1200]

D41 = subData41.valsIdx[1200]
D42 = subData42.valsIdx[1200]
D43 = subData43.valsIdx[1200]
D44 = subData44.valsIdx[1200]

print np.array([[D110, D120, D130, D140], [D11, D12, D13, D14], [D21, D22, D23, D24], [D31, D32, D33, D34]])
# Out:
# [[ 5.92660384  5.93499289  5.94459279  6.90567804]
#  [ 5.85415113  5.86230967  5.87119233  6.66713298]
#  [ 5.63937852  5.64528566  5.65174954  6.15519804]
#  [ 5.4719552   5.47762322  5.48376177  5.83485747]]

# %%
stateLabel = "Cai"

subData1 = ao.GetData(data54,stateLabel)
subData2 = ao.GetData(data64,stateLabel)
subData3 = ao.GetData(data74,stateLabel)
subData4 = ao.GetData(data84,stateLabel)

# %%
ca1 = max(subData1.valsIdx[2000:4000])
ca2 = max(subData2.valsIdx[2000:4000])
ca3 = max(subData3.valsIdx[2000:4000])
ca4 = max(subData4.valsIdx[2000:4000])
ca5 = max(subData5.valsIdx[2000:4000])

cas = np.array([ca1,ca2,ca3,ca4,ca5])
camax = max(cas)

car = cas/camax

rest = np.array([50,100,200,300,900])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(rest,car,'k--s',label="ST50 - 1 mM ATP")
plt.xlabel("Resting term (sec)",fontsize=15)
plt.ylabel("Relative [Ca] (fraction of max)")

plt.ylim(0.4,1.02)
plt.xlim(0,920)

plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqrelplot.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data2,stateLabel)
subData3 = ao.GetData(data3,stateLabel)
subData4 = ao.GetData(data4,stateLabel)
subData5 = ao.GetData(data5,stateLabel)

tnfa1 = max(subData1.valsIdx[2000:4000])
tnfa2 = max(subData2.valsIdx[2000:4000])
tnfa3 = max(subData3.valsIdx[2000:4000])
tnfa4 = max(subData4.valsIdx[2000:4000])
tnfa5 = max(subData5.valsIdx[2000:4000])

tnfas = np.array([tnfa1,tnfa2,tnfa3,tnfa4,tnfa5])
tnfamax = max(tnfas)

tnfar = tnfas/tnfamax

rest = np.array([50,100,200,300,900])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(rest,tnfar,'k--s',label="ST50 - 1 mM ATP")
plt.xlabel("Resting term (sec)",fontsize=15)
plt.ylabel("Relative [tnfa] (fraction of max)")

plt.ylim(0.2,1.02)
plt.xlim(0,920)

plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfavsfreqrelplot.png")
