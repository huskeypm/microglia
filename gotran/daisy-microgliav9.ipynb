# %%
# %matplotlib inline

import matplotlib.pylab as plt 


# routlines for analyzing odes
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/pkh-code/fitting')
import analyzeGotran as ao

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/1min_MG_1mMATP3_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_1mMATP3_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/30min_MG_1mMATP3_cat.pickle")
data4 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_1mMATP3_cat.pickle")

data5 = ao.readPickle("/home/AD/bch265/Data_storage/1min_MG_3mMATP3_cat.pickle")
data6 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_3mMATP3_cat.pickle")
data7 = ao.readPickle("/home/AD/bch265/Data_storage/30min_MG_3mMATP3_cat.pickle")
data8 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_3mMATP3_cat.pickle")

data9 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_0mMATP3_cat.pickle")
data10 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_01mMATP3_cat.pickle")
data11 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_05mMATP3_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/15min_MG_5mMATP3_cat.pickle")

data13 = ao.readPickle("/home/AD/bch265/Data_storage/5min_MG_1mMATP3_cat.pickle")
data14 = ao.readPickle("/home/AD/bch265/Data_storage/10min_MG_1mMATP3_cat.pickle")

data15 = ao.readPickle("/home/AD/bch265/Data_storage/5min_MG_3mMATP3_cat.pickle")
data16 = ao.readPickle("/home/AD/bch265/Data_storage/10min_MG_3mMATP3_cat.pickle")

data17 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_001mMATP3_cat.pickle")
data18 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_01mMATP3_cat.pickle")
data19 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_1mMATP3_cat.pickle")

# %%
data20 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_0.01mMATP2_cat.pickle")
data21 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_0.1mMATP2_cat.pickle")
data22 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_1mMATP2_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/180min_MG_0.01mMATP2_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_0.1mMATP2_cat.pickle
# Reading /home/AD/bch265/Data_storage/180min_MG_1mMATP2_cat.pickle

# %%
data26 = ao.readPickle("/home/AD/bch265/Data_storage/180min_MG_0.2mMATP2_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/180min_MG_0.2mMATP2_cat.pickle

# %%
data23 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_0.01mMATP2_cat.pickle")
data24 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_0.1mMATP2_cat.pickle")
data25 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_1mMATP2_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/60min_MG_0.01mMATP2_cat.pickle
# Reading /home/AD/bch265/Data_storage/60min_MG_0.1mMATP2_cat.pickle
# Reading /home/AD/bch265/Data_storage/60min_MG_1mMATP2_cat.pickle

# %%
data27 = ao.readPickle("/home/AD/bch265/Data_storage/60min_MG_0.2mMATP2_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/60min_MG_0.2mMATP2_cat.pickle

# %%
data28 = ao.readPickle("/home/AD/bch265/Data_storage/1hr_MG_3mMATP_cat.pickle")
data29 = ao.readPickle("/home/AD/bch265/Data_storage/2hr_MG_3mMATP_cat.pickle")
data30 = ao.readPickle("/home/AD/bch265/Data_storage/3hr_MG_3mMATP_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/1hr_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/2hr_MG_3mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/3hr_MG_3mMATP_cat.pickle

# %%
data1.keys()
data2.keys()
data3.keys()
data4.keys()
data5.keys()
data6.keys()
data7.keys()
data8.keys()
data9.keys()
data10.keys()
data11.keys()
data12.keys()
data13.keys()
data14.keys()
data15.keys()
data16.keys()
data17.keys()
data18.keys()
data19.keys()
# Out:
# ['s_idx', 'p_idx', 'j', 'p', 's', 'j_idx', 't']

# %%
data20.keys()
data21.keys()
data22.keys()

data23.keys()
data24.keys()
data25.keys()

data28.keys()
data29.keys()
data30.keys()
# Out:
# ['s_idx', 'p_idx', 'j', 'p', 's', 'j_idx', 't']

# %%
stateLabel = "NFATNn"
subData1 = ao.GetData(data9,stateLabel)
subData2 = ao.GetData(data10,stateLabel)
subData3 = ao.GetData(data11,stateLabel)
subData4 = ao.GetData(data2,stateLabel)
subData5 = ao.GetData(data6,stateLabel)
subData6 = ao.GetData(data12,stateLabel)

start = 0
end = 10000
plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(subData1.t[start:end]*1000,subData1.valsIdx[start:end],'b-',label="1")
plt.plot(subData2.t[start:end]*1000,subData2.valsIdx[start:end],'r-',label="5")
plt.plot(subData3.t[start:end]*1000,subData3.valsIdx[start:end],'g-',label="10")
plt.plot(subData4.t[start:end]*1000,subData4.valsIdx[start:end],'k-',label="15")
plt.plot(subData5.t[start:end]*1000,subData5.valsIdx[start:end],'m-',label="30")
plt.plot(subData6.t[start:end]*1000,subData6.valsIdx[start:end],'c-',label="60")

plt.legend(fontsize=12)
plt.xlabel("time (s)",fontsize=15)
#plt.ylabel("Current (nA)",fontsize=15)
#plt.xlim(2000,2900)
#plt.ylim(0.6,1)
#plt.gcf().savefig("x.png")

# %%
stateLabel = "NFATNn"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data13,stateLabel)
subData3 = ao.GetData(data14,stateLabel)
subData4 = ao.GetData(data2,stateLabel)
subData5 = ao.GetData(data3,stateLabel)
subData6 = ao.GetData(data4,stateLabel)

NFAT0 = max(subData1.valsIdx[500:900])
NFAT1 = max(subData1.valsIdx[4000:7000])
NFAT2 = max(subData2.valsIdx[4000:7000])
NFAT3 = max(subData3.valsIdx[4000:7000])
NFAT4 = max(subData4.valsIdx[4000:7000])
NFAT5 = max(subData5.valsIdx[4000:7000])
NFAT6 = max(subData6.valsIdx[4000:7000])

NFAT = np.array([NFAT0,NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])
maxN = max(NFAT)
NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT2/maxN,NFAT3/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])
dura = np.array([0,1,5,10,15,30,60])
LitNFATr = np.array([0,0.26,0.95,1,0.95])
Littime = np.array([0,1,15,31,60])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(dura,NFATr,'r--x',label="Model at 1 mM [ATP]")
plt.plot(Littime,LitNFATr,'b--x',label="Expt. at 3 mM [ATP]")

plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP exposure time (min)",fontsize=15)
plt.ylabel("Relative NFAT conc. (Fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/NFATvsExpTime1mMATP2.png")

# %%
stateLabel = "NFATNn"
subData1 = ao.GetData(data5,stateLabel)
#subData2 = ao.GetData(data15,stateLabel)
#subData3 = ao.GetData(data16,stateLabel)
subData4 = ao.GetData(data6,stateLabel)
subData5 = ao.GetData(data7,stateLabel)
subData6 = ao.GetData(data8,stateLabel)

NFAT0 = max(subData1.valsIdx[500:900])
NFAT1 = max(subData1.valsIdx[4000:7000])
#NFAT2 = max(subData2.valsIdx[4000:7000])
#NFAT3 = max(subData3.valsIdx[4000:7000])
NFAT4 = max(subData4.valsIdx[4000:7000])
NFAT5 = max(subData5.valsIdx[4000:7000])
NFAT6 = max(subData6.valsIdx[4000:7000])

#NFAT = np.array([NFAT0,NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])
NFAT = np.array([NFAT0,NFAT1,NFAT4,NFAT5,NFAT6])
maxN = max(NFAT)
#NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT2/maxN,NFAT3/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])
NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])

dura = np.array([0,1,5,10,15,30,60])
LitNFATr = np.array([0,0.26,0.95,1,0.95])
Littime = np.array([0,1,15,31,60])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(Littime,NFATr,'r--x',label="Model at 3 mM [ATP]")
plt.plot(Littime,LitNFATr,'b--x',label="Ferrari et. al., at 3 mM [ATP]")

plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP exposure time (min)",fontsize=15)
plt.ylabel("Relative NFAT conc. (Fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/NFATvsExpTime3mMATP2.png")

# %%
stateLabel = "pp38"
subData1 = ao.GetData(data5,stateLabel)
#subData2 = ao.GetData(data15,stateLabel)
#subData3 = ao.GetData(data16,stateLabel)
subData4 = ao.GetData(data6,stateLabel)
subData5 = ao.GetData(data7,stateLabel)
subData6 = ao.GetData(data8,stateLabel)

NFAT0 = max(subData1.valsIdx[500:900])
NFAT1 = max(subData1.valsIdx[4000:7000])
#NFAT2 = max(subData2.valsIdx[4000:7000])
#NFAT3 = max(subData3.valsIdx[4000:7000])
NFAT4 = max(subData4.valsIdx[4000:7000])
NFAT5 = max(subData5.valsIdx[4000:7000])
NFAT6 = max(subData6.valsIdx[4000:7000])

#NFAT = np.array([NFAT0,NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])
NFAT = np.array([NFAT0,NFAT1,NFAT4,NFAT5,NFAT6])
maxN = max(NFAT)
#NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT2/maxN,NFAT3/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])
NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])

dura = np.array([0,1,5,10,15,30,60])
LitNFATr = np.array([0,0.26,0.95,1,0.95])
Littime = np.array([0,1,15,31,60])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(Littime,NFATr,'r--x',label="Model at 3 mM [ATP]")
#plt.plot(Littime,LitNFATr,'b--x',label="Expt. at 3 mM [ATP]")

plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP exposure time (min)",fontsize=15)
plt.ylabel("Relative phophorylated p38 (Fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/pp38vsExpTime3mMATP2.png")

# %%
stateLabel = "NFATNn"
#subData1 = ao.GetData(data9,stateLabel)
subData2 = ao.GetData(data10,stateLabel)
subData3 = ao.GetData(data11,stateLabel)
subData4 = ao.GetData(data2,stateLabel)
subData5 = ao.GetData(data6,stateLabel)
subData6 = ao.GetData(data12,stateLabel)

NFAT1 = max(subData2.valsIdx[500:900])
NFAT2 = max(subData2.valsIdx[start:end])
NFAT3 = max(subData3.valsIdx[start:end])
NFAT4 = max(subData4.valsIdx[start:end])
NFAT5 = max(subData5.valsIdx[start:end])
NFAT6 = max(subData6.valsIdx[start:end])

NFAT = np.array([NFAT1,NFAT2,NFAT3,NFAT4,NFAT5,NFAT6])
#NFAT = np.array([NFAT0,NFAT1,NFAT4,NFAT5,NFAT6])
maxN = max(NFAT)
NFATr = np.array([NFAT1/maxN,NFAT2/maxN,NFAT3/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])
#NFATr = np.array([NFAT0/maxN,NFAT1/maxN,NFAT4/maxN,NFAT5/maxN,NFAT6/maxN])

#dura = np.array([0,1,5,10,15,30,60])
ATPmM = np.array([0,0.1,0.5,1,3,5]) 
LitNFATr = np.array([0,0.05,0.1,0.5,1,0.3])
#Littime = np.array([0,1,15,31,60])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(ATPmM,NFATr,'r--x',label="Model for 15 min")
plt.plot(ATPmM,LitNFATr,'b--x',label="Ferrari et. al., for 15 min")

plt.legend(loc=0,fontsize=12)
plt.xlabel("ATP conc. (mM)",fontsize=15)
plt.ylabel("Relative NFAT conc. (Fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/nfatvsATPconc15min.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data20,stateLabel)
subData2 = ao.GetData(data21,stateLabel)
subData3 = ao.GetData(data22,stateLabel)
subData4 = ao.GetData(data26,stateLabel)

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(subData1.t*1000,subData1.valsIdx,'b-',label="0.01 mM ATP")
plt.plot(subData2.t*1000,subData2.valsIdx,'r-',label="0.1 mM ATP")
plt.plot(subData4.t*1000,subData4.valsIdx,'k-',label="0.2 mM ATP")
plt.plot(subData3.t*1000,subData3.valsIdx,'g-',label="1 mM ATP")
#plt.plot(subData6.t*1000,subData6.valsIdx,'c-',label="5")

plt.legend(loc=0,fontsize=12)
plt.xlabel("time (s)",fontsize=15)
plt.ylabel("Current (nA)",fontsize=15)
plt.xlim(11800,21600)
plt.ylim(0.0,75)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvsATP3hr.png")
#plt.gcf().savefig("x.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data20,stateLabel)
subData2 = ao.GetData(data21,stateLabel)
subData3 = ao.GetData(data22,stateLabel)
subData4 = ao.GetData(data26,stateLabel)

tnfa1 = subData1.valsIdx[21600]
tnfa2 = subData2.valsIdx[21600]
tnfa3 = subData4.valsIdx[21600]
tnfa4 = subData3.valsIdx[21600]

tnfar = np.array([tnfa1/tnfa4, tnfa2/tnfa4, tnfa3/tnfa4, 1])
ATP = np.array([0.01,0.1,0.2,1])
Hide = np.array([0.04,0.26,0.35,1])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.semilogx(ATP,tnfar,'b--o',label="Model - 3 hr")
plt.semilogx(ATP,Hide,'r--s',label="Hide et al. - 3 hr")

plt.xlim(0.009,1.2)
plt.ylim(0,1.05)

plt.legend(loc=0,fontsize=12)
plt.xlabel("log[ATP] (log(mM))",fontsize=15)
plt.ylabel("Relative TNFa released (fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvsATP3hr2.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data23,stateLabel)
subData2 = ao.GetData(data24,stateLabel)
subData3 = ao.GetData(data25,stateLabel)
subData4 = ao.GetData(data27,stateLabel)

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(subData1.t*1000,subData1.valsIdx,'b-',label="0.01 mM ATP")
plt.plot(subData2.t*1000,subData2.valsIdx,'r-',label="0.1 mM ATP")
plt.plot(subData4.t*1000,subData4.valsIdx,'k-',label="0.2 mM ATP")
plt.plot(subData3.t*1000,subData3.valsIdx,'g-',label="1 mM ATP")
#plt.plot(subData5.t*1000,subData5.valsIdx,'m-',label="3")
#plt.plot(subData6.t*1000,subData6.valsIdx,'c-',label="5")

plt.legend(fontsize=12)
plt.xlabel("time (s)",fontsize=15)
plt.ylabel("Current (nA)",fontsize=15)
plt.xlim(4600,8200)
plt.ylim(0.0,20)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvsATP3hr.png")
#plt.gcf().savefig("x.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data23,stateLabel)
subData2 = ao.GetData(data24,stateLabel)
subData3 = ao.GetData(data25,stateLabel)
subData4 = ao.GetData(data27,stateLabel)

tnfa1 = subData1.valsIdx[8200]
tnfa2 = subData2.valsIdx[8200]
tnfa3 = subData4.valsIdx[8200]
tnfa4 = subData3.valsIdx[8200]

tnfar = np.array([tnfa1/tnfa4, tnfa2/tnfa4, tnfa3/tnfa4, 1])
ATP = np.array([0.01,0.1,0.2,1])
Hide = np.array([0.04,0.26,0.35,1])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.semilogx(ATP,tnfar,'b--o',label="Model - 1 hr")
plt.semilogx(ATP,Hide,'r--s',label="Hide et al. - 3 hr")

plt.xlim(0.009,1.2)
plt.ylim(0,1.05)

plt.legend(loc=0,fontsize=12)
plt.xlabel("log[ATP] (log(mM))",fontsize=15)
plt.ylabel("Relative TNFa released (fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvsATP1hr2.png")

# %%
stateLabel = "TNFa_release"
subData1 = ao.GetData(data28,stateLabel)
subData2 = ao.GetData(data29,stateLabel)
subData3 = ao.GetData(data30,stateLabel)

tnfa1 = subData1.valsIdx[8200]
tnfa2 = subData2.valsIdx[15400]
tnfa3 = subData3.valsIdx[21600]

tnfar = np.array([0,tnfa1/tnfa3, tnfa2/tnfa3, tnfa3/tnfa3])
hrs = np.array([0,1,2,3])
Hide = np.array([0,0.054,0.54,1])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(hrs,tnfar,'b--o',label="Model - 3 mM ATP")
plt.plot(hrs,Hide,'r--s',label="Hide et al. - 3 mM ATP")

plt.xlim(-0.2,3.2)
plt.ylim(-0.05,1.05)

plt.legend(loc=0,fontsize=12)
plt.xlabel("time (hr)",fontsize=15)
plt.ylabel("Relative TNFa released (fraction of max)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvstime3mMATP.png")
