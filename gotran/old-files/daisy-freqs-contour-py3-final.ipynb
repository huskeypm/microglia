# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
Z = np.array([[ 0.08132838,  0.08133058,  0.08145692,  0.08191949,  0.08390235],
 [ 0.08132838,  0.08133889,  0.08181232,  0.08284722,  0.08809624],
 [ 0.08132838,  0.08135033,  0.08201561,  0.0834152 ,  0.09193648],
 [ 0.08132838,  0.08136345,  0.08217615,  0.08381763,  0.09543591],
 [ 0.08132838,  0.08137481,  0.08235875,  0.08437105,  0.09793336]])

z = np.array([ 0.08132838,  0.08133058,  0.08145692,  0.08191949,  0.08390235,  0.08132838,
  0.08133889 , 0.08181232 , 0.08284722,  0.08809624,  0.08132838,  0.08135033,
  0.08201561 , 0.0834152  , 0.09193648,  0.08132838,  0.08136345,  0.08217615,
  0.08381763 , 0.09543591 , 0.08132838,  0.08137481,  0.08235875,  0.08437105,
  0.09793336])

plt.figure(figsize=(7,8),dpi=100)
plt.tick_params(labelsize=12)
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                cmap=cm.gray, extent=(0, 1000, 1, 19),aspect='auto')
levels = np.arange(min(z), max(z), (max(z)-min(z))/6)
CS = plt.contour(Z, 0.082,
                 origin='lower',
                 colors=('gold','palegreen','paleturquoise','mediumspringgreen','lawngreen','gold'),
                 linewidths=2,
                 extent=(0, 1000, 1, 19))

CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)
CBI.set_label('$[Ca^{2+}]_{i}$ conc. (uM)', fontsize=12)
plt.clabel(CS, inline=1, fontsize=12)
plt.xlabel("ATP conc. (uM)",fontsize=15)
plt.ylabel("Duration (sec)\n(20 sec of cycle)",fontsize=15)
plt.tight_layout()
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/contCaduravsATPnew.png")

# %%
z = np.array([  0.00265286,  0.00265328,  0.00267835,  0.00283703,  0.0033484,   0.00265286,
  0.00265475,  0.00275559,  0.00333661 , 0.00441488 , 0.00265286 , 0.0026562,
  0.00282001,  0.00366303,  0.00524987 , 0.00265286 , 0.00265762 , 0.0028625,
  0.00385833,  0.00590684,  0.00265286 , 0.00265866 , 0.00288325 , 0.003952,
  0.00626468])

Z = np.array([[ 0.00265286,  0.00265328,  0.00267835,  0.00283703,  0.0033484 ],
 [ 0.00265286 , 0.00265475 , 0.00275559 , 0.00333661 , 0.00441488],
 [ 0.00265286 , 0.0026562  , 0.00282001 , 0.00366303 , 0.00524987],
 [ 0.00265286 , 0.00265762 , 0.0028625  , 0.00385833 , 0.00590684],
 [ 0.00265286 , 0.00265866 , 0.00288325 , 0.003952   , 0.00626468]])/max(z)


plt.figure(figsize=(7,8),dpi=100)
plt.tick_params(labelsize=12)
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                cmap=cm.gray, extent=(0, 1000, 1, 19),aspect='auto')
levels = np.arange(0, 1, 0.1)
CS = plt.contour(Z, 0.45,
                 origin='lower',
                 colors=('gold','palegreen','paleturquoise','mediumspringgreen','lawngreen','gold','b','green','k'),
                 linewidths=2,
                 extent=(0, 1000, 1, 19))

CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)
CBI.set_label('TNFa synthesized(normalized by max)', fontsize=12)
plt.clabel(CS, inline=1, fontsize=12)
plt.xlabel("ATP conc. (uM)",fontsize=15)
plt.ylabel("Duration (sec)\n(20 sec of cycle)",fontsize=15)
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/contnormTNFaduravsATPnew.png")

# %%
z = np.array([ 0.08131934,  0.08134004,  0.08198226,  0.08363877,  0.09705178,  0.08131934,
  0.08132431,  0.08166879,  0.08255301,  0.09082197,  0.08131934,  0.08132159,
  0.08153974,  0.08216897,  0.08652083,  0.08131934,  0.08132095,  0.08144909,
  0.08191949,  0.08390235,  0.08131934,  0.08132068,  0.0814097 ,  0.08177725,
  0.08294849,  0.08131934,  0.0813217 ,  0.08137465,  0.08160132,  0.08217694,
  0.08131934,  0.08131997,  0.08135555,  0.08152377,  0.08192037])

Z = np.array([[ 0.08131934,  0.08131997 , 0.08135555 , 0.08152377 , 0.08192037],
 [ 0.08131934 , 0.0813217  , 0.08137465 , 0.08160132 , 0.08217694],
 [ 0.08131934 , 0.08132068 , 0.0814097  , 0.08177725 , 0.08294849],
 [ 0.08131934 , 0.08132095 , 0.08144909 , 0.08191949 , 0.08390235],
 [ 0.08131934 , 0.08132159 , 0.08153974 , 0.08216897 , 0.08652083],
 [ 0.08131934 , 0.08132431 , 0.08166879 , 0.08255301 , 0.09082197],
 [ 0.08131934 , 0.08134004 , 0.08198226 , 0.08363877 , 0.09705178]])

plt.figure(figsize=(7,8),dpi=100)
plt.tick_params(labelsize=12)
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                cmap=cm.gray, extent=(0, 1000, 0.0167, 0.5),aspect='auto')
levels = np.arange(min(z), max(z), (max(z)-min(z))/20)
CS = plt.contour(Z, 0.082,
                 origin='lower',
                 colors=('gold','palegreen','paleturquoise','mediumspringgreen','lawngreen','gold','b','green','k'),
                 linewidths=2,
                 extent=(0, 1000, 0.0167, 0.5))

CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)
CBI.set_label('$[Ca^{2+}]_{i}$ conc. (uM)', fontsize=12)
plt.clabel(CS, inline=1, fontsize=12)
plt.xlabel("ATP conc. (uM)",fontsize=15)
plt.tight_layout()
plt.ylabel("Frequency (Hz)\n (1 sec of stimulation)",fontsize=15)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/contCaPeriodvsATPnew.png")
# Out:
# Text(45.7222,0.5,'Frequency (Hz)\n (1 sec of stimulation)')

# %%
x = np.array([0,1,10,100,1000])
y = np.array([1,10,20,30])
X, Y = np.meshgrid(x, y)

z = np.array([ 0.00253868,  0.0025415 ,  0.00269213,  0.00350034,  0.00596065,  0.00253868,
  0.00253958 , 0.00260388 , 0.00300884,  0.00439283,  0.00253868,  0.00253925,
  0.0025787  , 0.00283711 , 0.00370303,  0.00253868,  0.00253916,  0.00256916,
  0.00275633 , 0.00336125 , 0.00253868,  0.00253913,  0.00256592, 0.00272759,
  0.00325067 , 0.00253868 , 0.00253907,  0.00256176,  0.00269563,  0.00314063,
  0.00253868 , 0.00253905 , 0.00256068,  0.00268756,  0.00311329])

Z = np.array([[ 0.00253868,  0.00253905 , 0.00256068 , 0.00268756 , 0.00311329],
 [ 0.00253868 , 0.00253907 , 0.00256176 , 0.00269563 , 0.00314063],
 [ 0.00253868 , 0.00253913 , 0.00256592 , 0.00272759 , 0.00325067],
 [ 0.00253868 , 0.00253916 , 0.00256916 , 0.00275633 , 0.00336125],
 [ 0.00253868 , 0.00253925 , 0.0025787  , 0.00283711 , 0.00370303],
 [ 0.00253868 , 0.00253958 , 0.00260388 , 0.00300884 , 0.00439283],
 [ 0.00253868 , 0.0025415  , 0.00269213 , 0.00350034 , 0.00596065]])/max(z)


plt.figure(figsize=(7,8),dpi=100)
plt.tick_params(labelsize=12)
im = plt.imshow(Z, interpolation='bilinear', origin='lower',
                cmap=cm.gray, extent=(0, 1000, 0.0167, 0.5),aspect='auto')
levels = np.arange(0, 1, 0.1)
CS = plt.contour(Z, 0.45,
                 origin='lower',
                 colors=('gold','palegreen','paleturquoise','mediumspringgreen','lawngreen'),#,'gold','b','green','k'),
                 linewidths=2,
                 extent=(0, 1000, 0.0167, 0.5))

CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)
CBI.set_label('TNFa synthesized (normalized by max)', fontsize=12)
plt.clabel(CS, inline=1, fontsize=12)
plt.xlabel("ATP conc. (uM)",fontsize=15)
plt.tight_layout()
plt.ylabel("Frequency (Hz)\n (1 sec of stimulation)",fontsize=15)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/contnormTNFaPeriodvsATPnew.png")
# Out:
# Text(45.7222,0.5,'Frequency (Hz)\n (1 sec of stimulation)')
