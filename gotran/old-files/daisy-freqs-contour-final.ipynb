# %%
# routlines for analyzing odes
# %matplotlib inline
import matplotlib.pylab as plto 
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/pkh-code/fitting')
import analyzeGotran as ao

import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
data11 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.001mMATPnew_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.01mMATPnew_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.1mMATPnew_cat.pickle")
data14 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_1mMATPnew_cat.pickle")

data21 = ao.readPickle("/home/AD/bch265/Data_storage/5st15rsMG_0.001mMATPnew_cat.pickle")
data22 = ao.readPickle("/home/AD/bch265/Data_storage/5st15rsMG_0.01mMATPnew_cat.pickle")
data23 = ao.readPickle("/home/AD/bch265/Data_storage/5st15rsMG_0.1mMATPnew_cat.pickle")
data24 = ao.readPickle("/home/AD/bch265/Data_storage/5st15rsMG_1mMATPnew_cat.pickle")

data31 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.001mMATPnew_cat.pickle")
data32 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.01mMATPnew_cat.pickle")
data33 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_0.1mMATPnew_cat.pickle")
data34 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_1mMATPnew_cat.pickle")

data41 = ao.readPickle("/home/AD/bch265/Data_storage/15st5rsMG_0.001mMATPnew_cat.pickle")
data42 = ao.readPickle("/home/AD/bch265/Data_storage/15st5rsMG_0.01mMATPnew_cat.pickle")
data43 = ao.readPickle("/home/AD/bch265/Data_storage/15st5rsMG_0.1mMATPnew_cat.pickle")
data44 = ao.readPickle("/home/AD/bch265/Data_storage/15st5rsMG_1mMATPnew_cat.pickle")

data51 = ao.readPickle("/home/AD/bch265/Data_storage/19st1rsMG_0.001mMATPnew_cat.pickle")
data52 = ao.readPickle("/home/AD/bch265/Data_storage/19st1rsMG_0.01mMATPnew_cat.pickle")
data53 = ao.readPickle("/home/AD/bch265/Data_storage/19st1rsMG_0.1mMATPnew_cat.pickle")
data54 = ao.readPickle("/home/AD/bch265/Data_storage/19st1rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/1st19rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st19rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st19rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st19rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st15rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st15rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st15rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/5st15rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/15st5rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data61 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.001mMATPnew_cat.pickle")
data62 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.01mMATPnew_cat.pickle")
data63 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_0.1mMATPnew_cat.pickle")
data64 = ao.readPickle("/home/AD/bch265/Data_storage/1st1rsMG_1mMATPnew_cat.pickle")

data71 = ao.readPickle("/home/AD/bch265/Data_storage/1st4rsMG_0.001mMATPnew_cat.pickle")
data72 = ao.readPickle("/home/AD/bch265/Data_storage/1st4rsMG_0.01mMATPnew_cat.pickle")
data73 = ao.readPickle("/home/AD/bch265/Data_storage/1st4rsMG_0.1mMATPnew_cat.pickle")
data74 = ao.readPickle("/home/AD/bch265/Data_storage/1st4rsMG_1mMATPnew_cat.pickle")

data81 = ao.readPickle("/home/AD/bch265/Data_storage/1st9rsMG_0.001mMATPnew_cat.pickle")
data82 = ao.readPickle("/home/AD/bch265/Data_storage/1st9rsMG_0.01mMATPnew_cat.pickle")
data83 = ao.readPickle("/home/AD/bch265/Data_storage/1st9rsMG_0.1mMATPnew_cat.pickle")
data84 = ao.readPickle("/home/AD/bch265/Data_storage/1st9rsMG_1mMATPnew_cat.pickle")

data91 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.001mMATPnew_cat.pickle")
data92 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.01mMATPnew_cat.pickle")
data93 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_0.1mMATPnew_cat.pickle")
data94 = ao.readPickle("/home/AD/bch265/Data_storage/1st19rsMG_1mMATPnew_cat.pickle")

data01 = ao.readPickle("/home/AD/bch265/Data_storage/1st29rsMG_0.001mMATPnew_cat.pickle")
data02 = ao.readPickle("/home/AD/bch265/Data_storage/1st29rsMG_0.01mMATPnew_cat.pickle")
data03 = ao.readPickle("/home/AD/bch265/Data_storage/1st29rsMG_0.1mMATPnew_cat.pickle")
data04 = ao.readPickle("/home/AD/bch265/Data_storage/1st29rsMG_1mMATPnew_cat.pickle")

data1a = ao.readPickle("/home/AD/bch265/Data_storage/1st49rsMG_0.001mMATPnew_cat.pickle")
data2a = ao.readPickle("/home/AD/bch265/Data_storage/1st49rsMG_0.01mMATPnew_cat.pickle")
data3a = ao.readPickle("/home/AD/bch265/Data_storage/1st49rsMG_0.1mMATPnew_cat.pickle")
data4a = ao.readPickle("/home/AD/bch265/Data_storage/1st49rsMG_1mMATPnew_cat.pickle")

data1b = ao.readPickle("/home/AD/bch265/Data_storage/1st59rsMG_0.001mMATPnew_cat.pickle")
data2b = ao.readPickle("/home/AD/bch265/Data_storage/1st59rsMG_0.01mMATPnew_cat.pickle")
data3b = ao.readPickle("/home/AD/bch265/Data_storage/1st59rsMG_0.1mMATPnew_cat.pickle")
data4b = ao.readPickle("/home/AD/bch265/Data_storage/1st59rsMG_1mMATPnew_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st1rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st4rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st4rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st4rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st4rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st9rsMG_0.001mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st9rsMG_0.01mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st9rsMG_0.1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st9rsMG_1mMATPnew_cat.pickle
# Reading /home/AD/bch265/Data_storage/1st19rsMG_0.001mMATPnew_cat.pickle
# ...

# %%
data0 = ao.readPickle("/home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle")
#stateLabel = "TNFa_release"
#subData0 = ao.GetData(data0,stateLabel)

#plt.plot(subData0.t/60,subData0.valsIdx)
# Out:
# Reading /home/AD/bch265/Data_storage/MG_0mMATP_cat.pickle

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data14,stateLabel)
subData2 = ao.GetData(data24,stateLabel)
subData3 = ao.GetData(data34,stateLabel)
subData4 = ao.GetData(data44,stateLabel)
subData5 = ao.GetData(data54,stateLabel)

lowx = 0
highx = 100

lowy = 0.07
highy = 0.14

ymin = lowy
ymax = highy
ytick = 0.02

plt.figure(figsize=(7,7),dpi=100)
ax = plt.subplot(5,1,1)
ax.tick_params(labelsize=12)
ax.plot((subData1.t) ,subData1.valsIdx,'b-',label="ST1/RS19")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))

labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,2)
ax.tick_params(labelsize=12)
ax.plot((subData2.t) ,subData2.valsIdx,'r-',label="ST5/RS15")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))

labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,3)
ax.tick_params(labelsize=12)
ax.plot((subData3.t) ,subData3.valsIdx,'g-',label="ST10/RS10")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))

labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,4)
ax.tick_params(labelsize=12)
ax.plot((subData4.t) ,subData4.valsIdx,'k-',label="ST15/RS5")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))

labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,1,5)
ax.tick_params(labelsize=12)
ax.plot((subData5.t) ,subData5.valsIdx,'m-',label="ST19/RS1")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))

ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew1mM.png")

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data64,stateLabel)
subData2 = ao.GetData(data74,stateLabel)
subData3 = ao.GetData(data84,stateLabel)
subData4 = ao.GetData(data94,stateLabel)
subData5 = ao.GetData(data04,stateLabel)
subData6 = ao.GetData(data4a,stateLabel)
subData7 = ao.GetData(data4b,stateLabel)

lowx = 0
highx = 100

lowy = 0.07
highy = 0.14

ymin = lowy
ymax = highy
ytick = 0.02

plt.figure(figsize=(7,10),dpi=100)
ax = plt.subplot(7,1,1)
ax.tick_params(labelsize=12)
ax.plot((subData1.t) ,subData1.valsIdx,'m-',label="0.5 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,2)
ax.tick_params(labelsize=12)
ax.plot((subData2.t) ,subData2.valsIdx,'b-',label="0.2 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,3)
ax.tick_params(labelsize=12)
ax.plot((subData3.t) ,subData3.valsIdx,'r-',label="0.1 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,4)
ax.tick_params(labelsize=12)
ax.plot((subData4.t) ,subData4.valsIdx,'g-',label="0.05 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,5)
ax.tick_params(labelsize=12)
ax.plot((subData5.t) ,subData5.valsIdx,'k-',label="0.033 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,6)
ax.tick_params(labelsize=12)
ax.plot((subData6.t) ,subData6.valsIdx,'m-',label="0.02 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,1,7)
ax.tick_params(labelsize=12)
ax.plot((subData7.t) ,subData7.valsIdx,'r',label="0.0167 Hz")
ax.legend(loc=0,fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(lowy,highy)
plt.xlim(lowx,highx)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduranew1mM.png")

# %%
stateLabel = "Cai"

subData0 = ao.GetData(data0,stateLabel)

subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)
subData51 = ao.GetData(data51,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)
subData52 = ao.GetData(data52,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)
subData53 = ao.GetData(data53,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)
subData54 = ao.GetData(data54,stateLabel)

D0 = min(subData0.valsIdx[150:200])

D11 = min(subData11.valsIdx[150:200])
D12 = min(subData12.valsIdx[150:200])
D13 = min(subData13.valsIdx[150:200])
D14 = min(subData14.valsIdx[150:200])

D21 = min(subData21.valsIdx[150:200])
D22 = min(subData22.valsIdx[150:200])
D23 = min(subData23.valsIdx[150:200])
D24 = min(subData24.valsIdx[150:200])

D31 = min(subData31.valsIdx[150:200])
D32 = min(subData32.valsIdx[150:200])
D33 = min(subData33.valsIdx[150:200])
D34 = min(subData34.valsIdx[150:200])

D41 = min(subData41.valsIdx[150:200])
D42 = min(subData42.valsIdx[150:200])
D43 = min(subData43.valsIdx[150:200])
D44 = min(subData44.valsIdx[150:200])

D51 = min(subData51.valsIdx[150:200])
D52 = min(subData52.valsIdx[150:200])
D53 = min(subData53.valsIdx[150:200])
D54 = min(subData54.valsIdx[150:200])

print np.array([[D0, D11, D12, D13, D14], 
                [D0, D21, D22, D23, D24], 
                [D0, D31, D32, D33, D34], 
                [D0, D41, D42, D43, D44], 
                [D0, D51, D52, D53, D54]])
print np.array([D0, D11, D12, D13, D14, D0, D21, D22, D23, D24, D0, D31, D32, D33, D34, D0, D41, D42, D43, D44, D0, D51, D52, D53, D54])
# Out:
# [[ 0.08132838  0.08133058  0.08145679  0.08191888  0.08389948]
#  [ 0.08132838  0.08133888  0.08181181  0.08284571  0.08808982]
#  [ 0.08132838  0.0813503   0.08201491  0.08341318  0.09192704]
#  [ 0.08132838  0.08136341  0.08217529  0.08381526  0.09542332]
#  [ 0.08132838  0.08137475  0.08235771  0.08436819  0.09791786]]
# [ 0.08132838  0.08133058  0.08145679  0.08191888  0.08389948  0.08132838
#   0.08133888  0.08181181  0.08284571  0.08808982  0.08132838  0.0813503
#   0.08201491  0.08341318  0.09192704  0.08132838  0.08136341  0.08217529
#   0.08381526  0.09542332  0.08132838  0.08137475  0.08235771  0.08436819
#   0.09791786]

# %%
stateLabel = "TNFa"

subData0 = ao.GetData(data0,stateLabel)

subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)
subData51 = ao.GetData(data51,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)
subData52 = ao.GetData(data52,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)
subData53 = ao.GetData(data53,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)
subData54 = ao.GetData(data54,stateLabel)


D0 = (subData0.valsIdx[100]-subData0.valsIdx[90])/0.167

D11 = (subData11.valsIdx[100]-subData11.valsIdx[90])/0.167
D12 = (subData12.valsIdx[100]-subData12.valsIdx[90])/0.167
D13 = (subData13.valsIdx[100]-subData13.valsIdx[90])/0.167
D14 = (subData14.valsIdx[100]-subData14.valsIdx[90])/0.167

D21 = (subData21.valsIdx[100]-subData21.valsIdx[90])/0.167
D22 = (subData22.valsIdx[100]-subData22.valsIdx[90])/0.167
D23 = (subData23.valsIdx[100]-subData23.valsIdx[90])/0.167
D24 = (subData24.valsIdx[100]-subData24.valsIdx[90])/0.167

D31 = (subData31.valsIdx[100]-subData31.valsIdx[90])/0.167
D32 = (subData32.valsIdx[100]-subData32.valsIdx[90])/0.167
D33 = (subData33.valsIdx[100]-subData33.valsIdx[90])/0.167
D34 = (subData34.valsIdx[100]-subData34.valsIdx[90])/0.167

D41 = (subData41.valsIdx[100]-subData41.valsIdx[90])/0.167
D42 = (subData42.valsIdx[100]-subData42.valsIdx[90])/0.167
D43 = (subData43.valsIdx[100]-subData43.valsIdx[90])/0.167
D44 = (subData44.valsIdx[100]-subData44.valsIdx[90])/0.167

D51 = (subData51.valsIdx[100]-subData51.valsIdx[90])/0.167
D52 = (subData52.valsIdx[100]-subData52.valsIdx[90])/0.167
D53 = (subData53.valsIdx[100]-subData53.valsIdx[90])/0.167
D54 = (subData54.valsIdx[100]-subData54.valsIdx[90])/0.167

print np.array([[D0, D11, D12, D13, D14], 
                [D0, D21, D22, D23, D24], 
                [D0, D31, D32, D33, D34], 
                [D0, D41, D42, D43, D44], 
                [D0, D51, D52, D53, D54]])
print np.array([D0, D11, D12, D13, D14, D0, D21, D22, D23, D24, D0, D31, D32, D33, D34, D0, D41, D42, D43, D44, D0, D51, D52, D53, D54])
# Out:
# [[ 0.00265286  0.00265328  0.00267835  0.00283703  0.0033484 ]
#  [ 0.00265286  0.00265475  0.00275559  0.00333661  0.00441488]
#  [ 0.00265286  0.0026562   0.00282001  0.00366303  0.00524987]
#  [ 0.00265286  0.00265762  0.0028625   0.00385833  0.00590684]
#  [ 0.00265286  0.00265866  0.00288325  0.003952    0.00626468]]
# [ 0.00265286  0.00265328  0.00267835  0.00283703  0.0033484   0.00265286
#   0.00265475  0.00275559  0.00333661  0.00441488  0.00265286  0.0026562
#   0.00282001  0.00366303  0.00524987  0.00265286  0.00265762  0.0028625
#   0.00385833  0.00590684  0.00265286  0.00265866  0.00288325  0.003952
#   0.00626468]

# %%
A = np.array([D0, D11, D12, D13, D14, D0, D21, D22, D23, D24, D31, D32, D33, D34, D41, D42, D43, D44,
              D51, D52, D53, D54])
maxTNFa = max(A)
st1 = np.array([D0, D11, D12, D13, D14])/maxTNFa
st5 = np.array([D0, D21, D22, D23, D24])/maxTNFa
st10 = np.array([D0, D31, D32, D33, D34])/maxTNFa
st15 = np.array([D0, D41, D42, D43, D44])/maxTNFa
st19 = np.array([D0, D51, D52, D53, D54])/maxTNFa

print st1
print st5
print st10
print st15
print st19
# Out:
# [ 0.42346353  0.42352958  0.42753244  0.45286179  0.53448925]
# [ 0.42346353  0.42376459  0.43986138  0.5326066   0.70472575]
# [ 0.42346353  0.42399678  0.45014389  0.58471124  0.83801066]
# [ 0.42346353  0.42422297  0.45692602  0.61588544  0.94287948]
# [ 0.42346353  0.42438822  0.4602396   0.6308375   1.        ]

# %%
stateLabel = "Cai"

subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)
subData51 = ao.GetData(data51,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)
subData52 = ao.GetData(data52,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)
subData53 = ao.GetData(data53,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)
subData54 = ao.GetData(data54,stateLabel)


xmin = 0
xmax = 100
ymin = 0.07
ymax = 0.16
ytick = 0.02

ind = np.arange(1, 6)

plt.figure(figsize=(18,15),dpi=150)
ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData11.t) ,subData11.valsIdx,'b-',label="ST20/ST20")
ax.set_ylabel("ST = 1 sec\n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData12.t) ,subData12.valsIdx,'b-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData13.t) ,subData13.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData14.t) ,subData14.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData21.t) ,subData21.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 5 sec\n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData22.t) ,subData22.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData23.t) ,subData23.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData24.t) ,subData24.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData31.t) ,subData31.valsIdx,'k',label="ST20/ST20")
ax.set_ylabel("ST = 10 sec\n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData32.t) ,subData32.valsIdx,'k',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData33.t) ,subData33.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData34.t) ,subData34.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st10, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData41.t) ,subData41.valsIdx,'g-',label="ST20/ST20")
ax.set_ylabel("ST = 15 sec\n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData42.t) ,subData42.valsIdx,'g-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData43.t) ,subData43.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData44.t) ,subData44.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st15, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData51.t) ,subData51.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 19 sec\n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData52.t) ,subData52.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData53.t) ,subData53.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData54.t) ,subData54.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st19, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()

# %%
#A = np.array([D0, D11, D12, D13, D14, D0, D21, D22, D23, D24, D0, D31, D32, D33, D34, D0, D41, D42, D43, D44, D0, D51, D52, D53, D54])
#maxTNFa = max(A)
#st1 = np.array([D0, D11, D12, D13, D14])/maxTNFa
#st5 = np.array([D0, D21, D22, D23, D24])/maxTNFa
#st10 = np.array([D0, D31, D32, D33, D34])/maxTNFa
#st15 = np.array([D0, D41, D42, D43, D44])/maxTNFa
#st19 = np.array([D0, D51, D52, D53, D54])/maxTNFa

stateLabel = "NFATNn"

subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)
subData51 = ao.GetData(data51,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)
subData52 = ao.GetData(data52,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)
subData53 = ao.GetData(data53,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)
subData54 = ao.GetData(data54,stateLabel)


xmin = 0
xmax = 100
ymin = 0.003
ymax = 0.0135
ytick = 0.002

ind = np.arange(1, 6)

plt.figure(figsize=(18,15),dpi=150)
ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData11.t) ,subData11.valsIdx,'b-',label="ST20/ST20")
ax.set_ylabel("ST = 1 sec\n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData12.t) ,subData12.valsIdx,'b-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData13.t) ,subData13.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData14.t) ,subData14.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData21.t) ,subData21.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 5 sec\n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData22.t) ,subData22.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData23.t) ,subData23.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData24.t) ,subData24.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData31.t) ,subData31.valsIdx,'k',label="ST20/ST20")
ax.set_ylabel("ST = 10 sec\n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData32.t) ,subData32.valsIdx,'k',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData33.t) ,subData33.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData34.t) ,subData34.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st10, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData41.t) ,subData41.valsIdx,'g-',label="ST20/ST20")
ax.set_ylabel("ST = 15 sec\n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData42.t) ,subData42.valsIdx,'g-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData43.t) ,subData43.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData44.t) ,subData44.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st15, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData51.t) ,subData51.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 19 sec\n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData52.t) ,subData52.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData53.t) ,subData53.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData54.t) ,subData54.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st19, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()

# %%
#A = np.array([D0, D11, D12, D13, D14, D0, D21, D22, D23, D24, D0, D31, D32, D33, D34, D0, D41, D42, D43, D44, D0, D51, D52, D53, D54])
#maxTNFa = max(A)
#st1 = np.array([D0, D11, D12, D13, D14])/maxTNFa
#st5 = np.array([D0, D21, D22, D23, D24])/maxTNFa
#st10 = np.array([D0, D31, D32, D33, D34])/maxTNFa
#st15 = np.array([D0, D41, D42, D43, D44])/maxTNFa
#st19 = np.array([D0, D51, D52, D53, D54])/maxTNFa

stateLabel = "pp38"

subData11 = ao.GetData(data11,stateLabel)
subData21 = ao.GetData(data21,stateLabel)
subData31 = ao.GetData(data31,stateLabel)
subData41 = ao.GetData(data41,stateLabel)
subData51 = ao.GetData(data51,stateLabel)

subData12 = ao.GetData(data12,stateLabel)
subData22 = ao.GetData(data22,stateLabel)
subData32 = ao.GetData(data32,stateLabel)
subData42 = ao.GetData(data42,stateLabel)
subData52 = ao.GetData(data52,stateLabel)

subData13 = ao.GetData(data13,stateLabel)
subData23 = ao.GetData(data23,stateLabel)
subData33 = ao.GetData(data33,stateLabel)
subData43 = ao.GetData(data43,stateLabel)
subData53 = ao.GetData(data53,stateLabel)

subData14 = ao.GetData(data14,stateLabel)
subData24 = ao.GetData(data24,stateLabel)
subData34 = ao.GetData(data34,stateLabel)
subData44 = ao.GetData(data44,stateLabel)
subData54 = ao.GetData(data54,stateLabel)


xmin = 0
xmax = 100
ymin = 2.5
ymax = 3.05
ytick = 0.1

ind = np.arange(1, 6)

plt.figure(figsize=(18,15),dpi=150)
ax = plt.subplot(5,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData11.t) ,subData11.valsIdx,'b-',label="ST20/ST20")
ax.set_ylabel("ST = 1 sec\np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData12.t) ,subData12.valsIdx,'b-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData13.t) ,subData13.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData14.t) ,subData14.valsIdx,'b-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData21.t) ,subData21.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 5 sec\np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData22.t) ,subData22.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData23.t) ,subData23.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData24.t) ,subData24.valsIdx,'r-',label="ST50/ST100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData31.t) ,subData31.valsIdx,'k',label="ST20/ST20")
ax.set_ylabel("ST = 10 sec\np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData32.t) ,subData32.valsIdx,'k',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData33.t) ,subData33.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData34.t) ,subData34.valsIdx,'k',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st10, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData41.t) ,subData41.valsIdx,'g-',label="ST20/ST20")
ax.set_ylabel("ST = 15 sec\np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData42.t) ,subData42.valsIdx,'g-',label="ST20/ST20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData43.t) ,subData43.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData44.t) ,subData44.valsIdx,'g-',label="ST20/ST20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st15, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData51.t) ,subData51.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("ST = 19 sec\np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(5,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData52.t) ,subData52.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData53.t) ,subData53.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData54.t) ,subData54.valsIdx,'m-',label="ST50/ST300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(5,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st19, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()

# %%
stateLabel = "Cai"
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData1b = ao.GetData(data1b,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData2b = ao.GetData(data2b,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData3b = ao.GetData(data3b,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData4b = ao.GetData(data4b,stateLabel)

subData0 = ao.GetData(data0,stateLabel)

D0 = min(subData0.valsIdx[120:200]) 

D61 = min(subData61.valsIdx[120:200]) 
D62 = min(subData62.valsIdx[120:200]) 
D63 = min(subData63.valsIdx[120:200]) 
D64 = min(subData64.valsIdx[120:200]) 

D71 = min(subData71.valsIdx[120:200]) 
D72 = min(subData72.valsIdx[120:200]) 
D73 = min(subData73.valsIdx[120:200]) 
D74 = min(subData74.valsIdx[120:200]) 

D81 = min(subData81.valsIdx[120:200]) 
D82 = min(subData82.valsIdx[120:200]) 
D83 = min(subData83.valsIdx[120:200]) 
D84 = min(subData84.valsIdx[120:200]) 

D91 = min(subData91.valsIdx[120:200]) 
D92 = min(subData92.valsIdx[120:200]) 
D93 = min(subData93.valsIdx[120:200]) 
D94 = min(subData94.valsIdx[120:200]) 

D01 = min(subData01.valsIdx[120:200]) 
D02 = min(subData02.valsIdx[120:200]) 
D03 = min(subData03.valsIdx[120:200]) 
D04 = min(subData04.valsIdx[120:200]) 

D1a = min(subData1a.valsIdx[120:200]) 
D2a = min(subData2a.valsIdx[120:200]) 
D3a = min(subData3a.valsIdx[120:200]) 
D4a = min(subData4a.valsIdx[120:200]) 

D1b = min(subData1b.valsIdx[120:200]) 
D2b = min(subData2b.valsIdx[120:200]) 
D3b = min(subData3b.valsIdx[120:200]) 
D4b = min(subData4b.valsIdx[120:200]) 


print np.array([[D0, D1b, D2b, D3b, D4b], 
                [D0, D1a, D2a, D3a, D4a], 
                [D0, D01, D02, D03, D04], 
                [D0, D91, D92, D93, D94], 
                [D0, D81, D82, D83, D84],
                [D0, D71, D72, D73, D74],
                [D0, D61, D62, D63, D64]])
                

print np.array([D0, D61, D62, D63, D64, 
                D0, D71, D72, D73, D74, 
                D0, D81, D82, D83, D84, 
                D0, D91, D92, D93, D94, 
                D0, D01, D02, D03, D04,
                D0, D1a, D2a, D3a, D4a,
                D0, D1b, D2b, D3b, D4b])
# Out:
# [[ 0.08131934  0.08131997  0.08135551  0.08152356  0.08191973]
#  [ 0.08131934  0.0813217   0.08137461  0.08160103  0.08217602]
#  [ 0.08131934  0.08132068  0.08140961  0.08177677  0.08294669]
#  [ 0.08131934  0.08132095  0.08144896  0.08191888  0.08389948]
#  [ 0.08131934  0.08132158  0.08153952  0.08216811  0.08651514]
#  [ 0.08131934  0.08132431  0.08166843  0.08255178  0.09081207]
#  [ 0.08131934  0.08134002  0.08198159  0.08363654  0.09703669]]
# [ 0.08131934  0.08134002  0.08198159  0.08363654  0.09703669  0.08131934
#   0.08132431  0.08166843  0.08255178  0.09081207  0.08131934  0.08132158
#   0.08153952  0.08216811  0.08651514  0.08131934  0.08132095  0.08144896
#   0.08191888  0.08389948  0.08131934  0.08132068  0.08140961  0.08177677
#   0.08294669  0.08131934  0.0813217   0.08137461  0.08160103  0.08217602
#   0.08131934  0.08131997  0.08135551  0.08152356  0.08191973]

# %%
stateLabel = "TNFa"
subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData1b = ao.GetData(data1b,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData2b = ao.GetData(data2b,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData3b = ao.GetData(data3b,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData4b = ao.GetData(data4b,stateLabel)



subData0 = ao.GetData(data0,stateLabel)

D0 = (subData0.valsIdx[120]-subData0.valsIdx[110])/0.167

D61 = (subData61.valsIdx[120]-subData61.valsIdx[110])/0.167
D62 = (subData62.valsIdx[120]-subData62.valsIdx[110])/0.167
D63 = (subData63.valsIdx[120]-subData63.valsIdx[110])/0.167
D64 = (subData64.valsIdx[120]-subData64.valsIdx[110])/0.167

D71 = (subData71.valsIdx[120]-subData71.valsIdx[110])/0.167
D72 = (subData72.valsIdx[120]-subData72.valsIdx[110])/0.167
D73 = (subData73.valsIdx[120]-subData73.valsIdx[110])/0.167
D74 = (subData74.valsIdx[120]-subData74.valsIdx[110])/0.167

D81 = (subData81.valsIdx[120]-subData81.valsIdx[110])/0.167
D82 = (subData82.valsIdx[120]-subData82.valsIdx[110])/0.167
D83 = (subData83.valsIdx[120]-subData83.valsIdx[110])/0.167
D84 = (subData84.valsIdx[120]-subData84.valsIdx[110])/0.167

D91 = (subData91.valsIdx[120]-subData91.valsIdx[110])/0.167
D92 = (subData92.valsIdx[120]-subData92.valsIdx[110])/0.167
D93 = (subData93.valsIdx[120]-subData93.valsIdx[110])/0.167
D94 = (subData94.valsIdx[120]-subData94.valsIdx[110])/0.167

D01 = (subData01.valsIdx[120]-subData01.valsIdx[110])/0.167
D02 = (subData02.valsIdx[120]-subData02.valsIdx[110])/0.167
D03 = (subData03.valsIdx[120]-subData03.valsIdx[110])/0.167
D04 = (subData04.valsIdx[120]-subData04.valsIdx[110])/0.167

D1a = (subData1a.valsIdx[120]-subData1a.valsIdx[110])/0.167
D2a = (subData2a.valsIdx[120]-subData2a.valsIdx[110])/0.167
D3a = (subData3a.valsIdx[120]-subData3a.valsIdx[110])/0.167
D4a = (subData4a.valsIdx[120]-subData4a.valsIdx[110])/0.167

D1b = (subData1b.valsIdx[120]-subData1b.valsIdx[110])/0.167
D2b = (subData2b.valsIdx[120]-subData2b.valsIdx[110])/0.167
D3b = (subData3b.valsIdx[120]-subData3b.valsIdx[110])/0.167
D4b = (subData4b.valsIdx[120]-subData4b.valsIdx[110])/0.167


print np.array([[D0, D1b, D2b, D3b, D4b], 
                [D0, D1a, D2a, D3a, D4a], 
                [D0, D01, D02, D03, D04], 
                [D0, D91, D92, D93, D94], 
                [D0, D81, D82, D83, D84],
                [D0, D71, D72, D73, D74],
                [D0, D61, D62, D63, D64]])
                

print np.array([D0, D61, D62, D63, D64, 
                D0, D71, D72, D73, D74, 
                D0, D81, D82, D83, D84, 
                D0, D91, D92, D93, D94, 
                D0, D01, D02, D03, D04,
                D0, D1a, D2a, D3a, D4a,
                D0, D1b, D2b, D3b, D4b])

a = np.array([D61,D71,D81,D91,D01,D1a,D1b])
A = a/max(a)

b = np.array([D62,D72,D82,D92,D02,D2a,D2b])
B = b/max(b)

c = np.array([D63,D73,D83,D93,D03,D3a,D3b])
C = c/max(c)

d = np.array([D64,D74,D84,D94,D04,D4a,D4b])
D = d/max(d)



ind = np.arange(1, 8)
plt.figure(figsize=(12,10),dpi=100)
ax = plt.subplot(2,2,1)
ax.tick_params(labelsize=12)
plt.title('[ATP] = 1 uM',fontsize=15)
ba,bb,bc,bd,be,bf,bg = ax.bar(ind, A, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
bf.set_facecolor('r')
bg.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0.4, 1.05])
ax.set_ylabel('TNFa synthesized per min (% of Max)',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0.5','0.2','0.1','0.05','0.033','0.02','0.0167'])
ax.set_xlabel('Freq. (Hz)',fontsize=15)
plt.tight_layout()

ax = plt.subplot(2,2,2)
ax.tick_params(labelsize=12)
plt.title('[ATP] = 10 uM',fontsize=15)
ba,bb,bc,bd,be,bf,bg = ax.bar(ind, B, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
bf.set_facecolor('r')
bg.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0.4, 1.05])
ax.set_ylabel('TNFa synthesized per min (% of Max)',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0.5','0.2','0.1','0.05','0.033','0.02','0.0167'])
ax.set_xlabel('Freq. (Hz)',fontsize=15)
plt.tight_layout()

ax = plt.subplot(2,2,3)
ax.tick_params(labelsize=12)
plt.title('[ATP] = 100 uM',fontsize=15)
ba,bb,bc,bd,be,bf,bg = ax.bar(ind, C, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
bf.set_facecolor('r')
bg.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0.4, 1.05])
ax.set_ylabel('TNFa synthesized per min (% of Max)',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0.5','0.2','0.1','0.05','0.033','0.02','0.0167'])
ax.set_xlabel('Freq. (Hz)',fontsize=15)
plt.tight_layout()

ax = plt.subplot(2,2,4)
ax.tick_params(labelsize=12)
plt.title('[ATP] = 1 mM',fontsize=15)
ba,bb,bc,bd,be,bf,bg = ax.bar(ind, D, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
bf.set_facecolor('r')
bg.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0.4, 1.05])
ax.set_ylabel('TNFa synthesized per min (% of Max)',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0.5','0.2','0.1','0.05','0.033','0.02','0.0167'],fontsize=12)
ax.set_xlabel('Freq. (Hz)',fontsize=15)
plt.tight_layout()
# Out:
# [[ 0.00253868  0.00253905  0.00256068  0.00268756  0.00311329]
#  [ 0.00253868  0.00253907  0.00256176  0.00269563  0.00314063]
#  [ 0.00253868  0.00253913  0.00256592  0.00272759  0.00325067]
#  [ 0.00253868  0.00253916  0.00256916  0.00275633  0.00336125]
#  [ 0.00253868  0.00253925  0.0025787   0.00283711  0.00370303]
#  [ 0.00253868  0.00253958  0.00260388  0.00300884  0.00439283]
#  [ 0.00253868  0.0025415   0.00269213  0.00350034  0.00596065]]
# [ 0.00253868  0.0025415   0.00269213  0.00350034  0.00596065  0.00253868
#   0.00253958  0.00260388  0.00300884  0.00439283  0.00253868  0.00253925
#   0.0025787   0.00283711  0.00370303  0.00253868  0.00253916  0.00256916
#   0.00275633  0.00336125  0.00253868  0.00253913  0.00256592  0.00272759
#   0.00325067  0.00253868  0.00253907  0.00256176  0.00269563  0.00314063
#   0.00253868  0.00253905  0.00256068  0.00268756  0.00311329]

# %%
A = np.array([D0, D61, D62, D63, D64, 
                D71, D72, D73, D74, 
                D81, D82, D83, D84, 
                D91, D92, D93, D94, 
                D01, D02, D03, D04,
                D1a, D2a, D3a, D4a,
                D1b, D2b, D3b, D4b])

maxTNFa = max(A)
st1 = np.array([D0, D61, D62, D63, D64])/maxTNFa
st2 = np.array([D0, D71, D72, D73, D74])/maxTNFa
st3 = np.array([D0, D81, D82, D83, D84])/maxTNFa
st4 = np.array([D0, D91, D92, D93, D94])/maxTNFa
st5 = np.array([D0, D01, D02, D03, D04])/maxTNFa
st6 = np.array([D0, D1a, D2a, D3a, D4a])/maxTNFa
st7 = np.array([D0, D1b, D2b, D3b, D4b])/maxTNFa

stateLabel = "Cai"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData1b = ao.GetData(data1b,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData2b = ao.GetData(data2b,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData3b = ao.GetData(data3b,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData4b = ao.GetData(data4b,stateLabel)

xmin = 0
xmax = 100
ymin = 0.07
ymax = 0.14
ytick = 0.02
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=100

#plt.figure(num=None, figsize=(30, 16), dpi=100, facecolor='w', edgecolor='k')
ax = plt.subplot(7,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.2 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.1 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.05 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.033 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,26)
ax.tick_params(labelsize=12)
ax.plot((subData1a.t) ,subData1a.valsIdx,'b',label="ST20/RS20")
ax.set_ylabel("0.02 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,27)
ax.tick_params(labelsize=12)
ax.plot((subData2a.t) ,subData2a.valsIdx,'b',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,28)
ax.tick_params(labelsize=12)
ax.plot((subData3a.t) ,subData3a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,29)
ax.tick_params(labelsize=12)
ax.plot((subData4a.t) ,subData4a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,30)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st6, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,31)
ax.tick_params(labelsize=12)
ax.plot((subData1b.t) ,subData1b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.0167 Hz \n[Ca]i (uM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(7,5,32)
ax.tick_params(labelsize=12)
ax.plot((subData2b.t) ,subData2b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,33)
ax.tick_params(labelsize=12)
ax.plot((subData3b.t) ,subData3b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,34)
ax.tick_params(labelsize=12)
ax.plot((subData4b.t) ,subData4b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,35)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st7, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()

# %%
A = np.array([D0, D61, D62, D63, D64, 
                D71, D72, D73, D74, 
                D81, D82, D83, D84, 
                D91, D92, D93, D94, 
                D01, D02, D03, D04,
                D1a, D2a, D3a, D4a,
                D1b, D2b, D3b, D4b])

maxTNFa = max(A)
st1 = np.array([D0, D61, D62, D63, D64])/maxTNFa
st2 = np.array([D0, D71, D72, D73, D74])/maxTNFa
st3 = np.array([D0, D81, D82, D83, D84])/maxTNFa
st4 = np.array([D0, D91, D92, D93, D94])/maxTNFa
st5 = np.array([D0, D01, D02, D03, D04])/maxTNFa
st6 = np.array([D0, D1a, D2a, D3a, D4a])/maxTNFa
st7 = np.array([D0, D1b, D2b, D3b, D4b])/maxTNFa

stateLabel = "NFATNn"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData1b = ao.GetData(data1b,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData2b = ao.GetData(data2b,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData3b = ao.GetData(data3b,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData4b = ao.GetData(data4b,stateLabel)

xmin = 0
xmax = 100
ymin = 0.003
ymax = 0.014
ytick = 0.002
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=150

#plt.figure(num=None, figsize=(30, 16), dpi=100, facecolor='w', edgecolor='k')
ax = plt.subplot(7,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.2 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.1 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.05 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.033 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,26)
ax.tick_params(labelsize=12)
ax.plot((subData1a.t) ,subData1a.valsIdx,'b',label="ST20/RS20")
ax.set_ylabel("0.02 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,27)
ax.tick_params(labelsize=12)
ax.plot((subData2a.t) ,subData2a.valsIdx,'b',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,28)
ax.tick_params(labelsize=12)
ax.plot((subData3a.t) ,subData3a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,29)
ax.tick_params(labelsize=12)
ax.plot((subData4a.t) ,subData4a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,30)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st6, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,31)
ax.tick_params(labelsize=12)
ax.plot((subData1b.t) ,subData1b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.0167 Hz \n[NFATN]n (nM)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(7,5,32)
ax.tick_params(labelsize=12)
ax.plot((subData2b.t) ,subData2b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,33)
ax.tick_params(labelsize=12)
ax.plot((subData3b.t) ,subData3b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,34)
ax.tick_params(labelsize=12)
ax.plot((subData4b.t) ,subData4b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,35)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st7, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()

# %%
A = np.array([D0, D61, D62, D63, D64, 
                D71, D72, D73, D74, 
                D81, D82, D83, D84, 
                D91, D92, D93, D94, 
                D01, D02, D03, D04,
                D1a, D2a, D3a, D4a,
                D1b, D2b, D3b, D4b])

maxTNFa = max(A)
st1 = np.array([D0, D61, D62, D63, D64])/maxTNFa
st2 = np.array([D0, D71, D72, D73, D74])/maxTNFa
st3 = np.array([D0, D81, D82, D83, D84])/maxTNFa
st4 = np.array([D0, D91, D92, D93, D94])/maxTNFa
st5 = np.array([D0, D01, D02, D03, D04])/maxTNFa
st6 = np.array([D0, D1a, D2a, D3a, D4a])/maxTNFa
st7 = np.array([D0, D1b, D2b, D3b, D4b])/maxTNFa

stateLabel = "pp38"

subData61 = ao.GetData(data61,stateLabel)
subData71 = ao.GetData(data71,stateLabel)
subData81 = ao.GetData(data81,stateLabel)
subData91 = ao.GetData(data91,stateLabel)
subData01 = ao.GetData(data01,stateLabel)
subData1a = ao.GetData(data1a,stateLabel)
subData1b = ao.GetData(data1b,stateLabel)

subData62 = ao.GetData(data62,stateLabel)
subData72 = ao.GetData(data72,stateLabel)
subData82 = ao.GetData(data82,stateLabel)
subData92 = ao.GetData(data92,stateLabel)
subData02 = ao.GetData(data02,stateLabel)
subData2a = ao.GetData(data2a,stateLabel)
subData2b = ao.GetData(data2b,stateLabel)

subData63 = ao.GetData(data63,stateLabel)
subData73 = ao.GetData(data73,stateLabel)
subData83 = ao.GetData(data83,stateLabel)
subData93 = ao.GetData(data93,stateLabel)
subData03 = ao.GetData(data03,stateLabel)
subData3a = ao.GetData(data3a,stateLabel)
subData3b = ao.GetData(data3b,stateLabel)

subData64 = ao.GetData(data64,stateLabel)
subData74 = ao.GetData(data74,stateLabel)
subData84 = ao.GetData(data84,stateLabel)
subData94 = ao.GetData(data94,stateLabel)
subData04 = ao.GetData(data04,stateLabel)
subData4a = ao.GetData(data4a,stateLabel)
subData4b = ao.GetData(data4b,stateLabel)

xmin = 0
xmax = 100
ymin = 2.5
ymax = 3.05
ytick = 0.1
ind = np.arange(1, 6)

rcParams['figure.figsize'] = 20,18
rcParams['figure.dpi']=150

#plt.figure(num=None, figsize=(30, 16), dpi=100, facecolor='w', edgecolor='k')
ax = plt.subplot(7,5,1)
ax.tick_params(labelsize=12)
ax.set_title("1 uM ATP",fontsize=15)
ax.plot((subData61.t) ,subData61.valsIdx,'b-',label="ST20/RS20")
ax.set_ylabel("0.5 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,2)
ax.tick_params(labelsize=12)
ax.set_title("10 uM ATP",fontsize=15)
ax.plot((subData62.t) ,subData62.valsIdx,'b-',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,3)
ax.tick_params(labelsize=12)
ax.set_title("100 uM ATP",fontsize=15)
ax.plot((subData63.t) ,subData63.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,4)
ax.tick_params(labelsize=12)
ax.set_title("1 mM ATP",fontsize=15)
ax.plot((subData64.t) ,subData64.valsIdx,'b-',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,5)
ax.tick_params(labelsize=12)
ax.set_title("Amt. of Synthesized TNFa",fontsize=15)
ba,bb,bc,bd,be = ax.bar(ind, st1, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,6)
ax.tick_params(labelsize=12)
ax.plot((subData71.t) ,subData71.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.2 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,7)
ax.tick_params(labelsize=12)
ax.plot((subData72.t) ,subData72.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,8)
ax.tick_params(labelsize=12)
ax.plot((subData73.t) ,subData73.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,9)
ax.tick_params(labelsize=12)
ax.plot((subData74.t) ,subData74.valsIdx,'r-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,10)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st2, align='center')
ba.set_facecolor('r')
bb.set_facecolor('r')
bc.set_facecolor('r')
bd.set_facecolor('r')
be.set_facecolor('r')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,11)
ax.tick_params(labelsize=12)
ax.plot((subData81.t) ,subData81.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.1 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,12)
ax.tick_params(labelsize=12)
ax.plot((subData82.t) ,subData82.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,13)
ax.tick_params(labelsize=12)
ax.plot((subData83.t) ,subData83.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,14)
ax.tick_params(labelsize=12)
ax.plot((subData84.t) ,subData84.valsIdx,'k-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,15)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st3, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,16)
ax.tick_params(labelsize=12)
ax.plot((subData91.t) ,subData91.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.05 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,17)
ax.tick_params(labelsize=12)
ax.plot((subData92.t) ,subData92.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,18)
ax.tick_params(labelsize=12)
ax.plot((subData93.t) ,subData93.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,19)
ax.tick_params(labelsize=12)
ax.plot((subData94.t) ,subData94.valsIdx,'g',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,20)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st4, align='center')
ba.set_facecolor('g')
bb.set_facecolor('g')
bc.set_facecolor('g')
bd.set_facecolor('g')
be.set_facecolor('g')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,21)
ax.tick_params(labelsize=12)
ax.plot((subData01.t) ,subData01.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.033 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,22)
ax.tick_params(labelsize=12)
ax.plot((subData02.t) ,subData02.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,23)
ax.tick_params(labelsize=12)
ax.plot((subData03.t) ,subData03.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,24)
ax.tick_params(labelsize=12)
ax.plot((subData04.t) ,subData04.valsIdx,'m-',label="ST50/RS100")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,25)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st5, align='center')
ba.set_facecolor('m')
bb.set_facecolor('m')
bc.set_facecolor('m')
bd.set_facecolor('m')
be.set_facecolor('m')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,26)
ax.tick_params(labelsize=12)
ax.plot((subData1a.t) ,subData1a.valsIdx,'b',label="ST20/RS20")
ax.set_ylabel("0.02 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,27)
ax.tick_params(labelsize=12)
ax.plot((subData2a.t) ,subData2a.valsIdx,'b',label="ST20/RS20")
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,28)
ax.tick_params(labelsize=12)
ax.plot((subData3a.t) ,subData3a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,29)
ax.tick_params(labelsize=12)
ax.plot((subData4a.t) ,subData4a.valsIdx,'b',label="ST20/RS20")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,30)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st6, align='center')
ba.set_facecolor('b')
bb.set_facecolor('b')
bc.set_facecolor('b')
bd.set_facecolor('b')
be.set_facecolor('b')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
#ax.set_xticklabels(['50','100','200','300'])
#ax.set_xlabel('Resting Period \n (50 sec duration)',fontsize=15)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
#ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,31)
ax.tick_params(labelsize=12)
ax.plot((subData1b.t) ,subData1b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
ax.set_ylabel("0.0167 Hz \np-p38 (molecule)",fontsize=15)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

ax = plt.subplot(7,5,32)
ax.tick_params(labelsize=12)
ax.plot((subData2b.t) ,subData2b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,33)
ax.tick_params(labelsize=12)
ax.plot((subData3b.t) ,subData3b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,34)
ax.tick_params(labelsize=12)
ax.plot((subData4b.t) ,subData4b.valsIdx,'k-',label="ST50/RS300")
#ax.legned(loc=0,fontsize=12)
plt.xlim(xmin,xmax)
plt.yticks(np.arange(ymin, ymax, ytick))
ax.set_xlabel("time (sec)",fontsize=15)
empty_string_labels = ['']*len(labels)
ax.set_yticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(7,5,35)
ax.tick_params(labelsize=12)
ba,bb,bc,bd,be = ax.bar(ind, st7, align='center')
ba.set_facecolor('k')
bb.set_facecolor('k')
bc.set_facecolor('k')
bd.set_facecolor('k')
be.set_facecolor('k')
ax.set_xticks(ind)
ax.set_ylim([0, 1])
ax.set_ylabel('Synthesized per min',fontsize=15)
ax.set_xticks(ind)
ax.set_xticklabels(['0','1','10','100','1000'])
ax.set_xlabel('[ATP] (uM)',fontsize=15)
plt.tight_layout()
