# %%
# routlines for analyzing odes
# %matplotlib inline
import matplotlib.pylab as plt 
import sys
import pickle as pk
import numpy as np
sys.path.append('/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/pkh-code/fitting')
import analyzeGotran as ao

# %%
data1 = ao.readPickle("/home/AD/bch265/Data_storage/50st50rsMG_1mMATP_cat.pickle")
data2 = ao.readPickle("/home/AD/bch265/Data_storage/50st100rsMG_1mMATP_cat.pickle")
data3 = ao.readPickle("/home/AD/bch265/Data_storage/50st200rsMG_1mMATP_cat.pickle")
data4 = ao.readPickle("/home/AD/bch265/Data_storage/50st300rsMG_1mMATP_cat.pickle")
data5 = ao.readPickle("/home/AD/bch265/Data_storage/50st900rsMG_1mMATP_cat.pickle")
data6 = ao.readPickle("/home/AD/bch265/Data_storage/100st100rsMG_1mMATP_cat.pickle")
data7 = ao.readPickle("/home/AD/bch265/Data_storage/100st800rsMG_1mMATP_cat.pickle")
data8 = ao.readPickle("/home/AD/bch265/Data_storage/200st200rsMG_1mMATP_cat.pickle")
data9 = ao.readPickle("/home/AD/bch265/Data_storage/200st400rsMG_1mMATP_cat.pickle")
data10 = ao.readPickle("/home/AD/bch265/Data_storage/10st10rsMG_1mMATP_cat.pickle")
data11 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_1mMATP_cat.pickle")
data12 = ao.readPickle("/home/AD/bch265/Data_storage/30st30rsMG_1mMATP_cat.pickle")
data13 = ao.readPickle("/home/AD/bch265/Data_storage/40st40rsMG_1mMATP_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/50st50rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st100rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st200rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st300rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/50st900rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/100st100rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/100st800rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/200st200rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/200st400rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/10st10rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/20st20rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/30st30rsMG_1mMATP_cat.pickle
# Reading /home/AD/bch265/Data_storage/40st40rsMG_1mMATP_cat.pickle

# %%
data11 = ao.readPickle("/home/AD/bch265/Data_storage/20st20rsMG_1mMATP_cat.pickle")
# Out:
# Reading /home/AD/bch265/Data_storage/20st20rsMG_1mMATP_cat.pickle

# %%
data1.keys()
data2.keys()
data3.keys()
data4.keys()
data5.keys()
data6.keys()
data7.keys()
data8.keys()
data9.keys()
data10.keys()
data11.keys()
data12.keys()
data13.keys()
# Out:
# ['s_idx', 'p_idx', 'j', 'p', 's', 'j_idx', 't']

# %%
stateLabel = "Cai"
subData1 = ao.GetData(data1,stateLabel)
subData2 = ao.GetData(data6,stateLabel)
subData3 = ao.GetData(data8,stateLabel)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreq2.png")

plt.figure(figsize=(7,8))
ax = plt.subplot(3,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData1.t*1000-1050,subData1.valsIdx,'b-',label="ST50/RS50")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.05,0.25)
plt.xlim(3000,4000)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(3,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData2.t*1000-1100,subData2.valsIdx,'r-',label="ST100/RS100")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.05,0.25)
plt.xlim(3000,4000)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(3,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData3.t*1000-4200,subData3.valsIdx,'g-',label="ST200/RS200")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.05,0.25)
plt.xlim(0,1000)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqduralong.png")

# %%
stateLabel = "Cai"
subData10 = ao.GetData(data10,stateLabel)
subData11 = ao.GetData(data11,stateLabel)
subData12 = ao.GetData(data12,stateLabel)
subData13 = ao.GetData(data13,stateLabel)
subData1 = ao.GetData(data1,stateLabel)
#plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreq2.png")


plt.figure(figsize=(7,10))
ax = plt.subplot(4,1,1)
ax.tick_params(labelsize=12)
ax.plot(subData10.t*1000-965,subData10.valsIdx,'b-',label="ST10/RS10")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.095,0.17)
plt.xlim(3500,4000)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,2)
ax.tick_params(labelsize=12)
ax.plot(subData12.t*1000-985,subData12.valsIdx,'g-',label="ST30/RS30")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.095,0.17)
plt.xlim(3500,4000)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,3)
ax.tick_params(labelsize=12)
ax.plot(subData12.t*1000-1000,subData13.valsIdx,'m-',label="ST40/RS40")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.095,0.17)
plt.xlim(3500,4000)
labels = [item.get_text() for item in ax.get_xticklabels()]
empty_string_labels = ['']*len(labels)
ax.set_xticklabels(empty_string_labels)
plt.tight_layout()

ax = plt.subplot(4,1,4)
ax.tick_params(labelsize=12)
ax.plot(subData1.t*1000-4500,subData1.valsIdx,'k-',label="ST50/RS50")
ax.legend(fontsize=12)
ax.set_ylabel("[Ca]i (uM)",fontsize=15)
plt.ylim(0.095,0.17)
plt.xlim(0,500)
ax.set_xlabel("time (sec)",fontsize=15)
plt.tight_layout()

plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsfreqdurashort.png")

# %%
stateLabel = "Cai"

subData1 = ao.GetData(data10,stateLabel)
subData2 = ao.GetData(data12,stateLabel)
subData3 = ao.GetData(data13,stateLabel)
subData4 = ao.GetData(data1,stateLabel)
subData5 = ao.GetData(data6,stateLabel)
subData6 = ao.GetData(data8,stateLabel)

ca1 = max(subData1.valsIdx[3000:4000])
ca2 = max(subData2.valsIdx[3000:4000])
ca3 = max(subData3.valsIdx[3000:4000])
ca4 = max(subData4.valsIdx[3000:4000])
ca5 = max(subData5.valsIdx[3000:4000])
ca6 = max(subData6.valsIdx[3000:4000])

cas = np.array([ca1,ca2,ca3,ca4,ca5,ca6])
camax = max(cas)

car = cas/camax

strs = np.array([10,30,40,50,100,200])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(strs,car,'k--s',label="1 mM ATP")
plt.xlabel("Stim(Rest) period (sec)",fontsize=15)
plt.ylabel("Relative [Ca] (fraction of max)")

plt.ylim(0.53,1.02)
plt.xlim(-10,210)

#plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/cavsdurarelplot.png")

# %%
stateLabel = "TNFa_release"

subData1 = ao.GetData(data10,stateLabel)
subData2 = ao.GetData(data12,stateLabel)
subData3 = ao.GetData(data13,stateLabel)
subData4 = ao.GetData(data1,stateLabel)
subData5 = ao.GetData(data6,stateLabel)
subData6 = ao.GetData(data8,stateLabel)

tnf1 = max(subData1.valsIdx[3000:4000])
tnf2 = max(subData2.valsIdx[3000:4000])
tnf3 = max(subData3.valsIdx[3000:4000])
tnf4 = max(subData4.valsIdx[3000:4000])
tnf5 = max(subData5.valsIdx[3000:4000])
tnf6 = max(subData6.valsIdx[3000:4000])

tnfs = np.array([tnf1,tnf2,tnf3,tnf4,tnf5,tnf6])
tnfmax = max(tnfs)

tnfr = tnfs/tnfmax

strs = np.array([10,30,40,50,100,200])

plt.figure(figsize=(7,7))
plt.tick_params(labelsize=12)
plt.plot(strs,tnfr,'k--s',label="1 mM ATP")
plt.xlabel("Stim(Rest) period (sec)",fontsize=15)
plt.ylabel("Relative TNFa released (fraction of max)")

plt.ylim(0.7,1.02)
plt.xlim(-10,210)

#plt.xticks(np.arange(0, 910, 100))
plt.tight_layout()
plt.savefig("/home/AD/bch265/Dropbox/Postdoctoral2017-/Modeling-Codes/repo/bens-paper/microglia04092018/tnfvsdurarelplot.png")
